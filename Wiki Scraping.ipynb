# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import json
import requests

# %%
query_url = "https://wiki.puella-magi.net/Iroha_Tamaki"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')
#final_result = soup.find_all('td', class_='fooinfo')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Iroha Tamaki - Puella Magi Wiki\n  </title>\n  <script src="/cdn-cgi/apps/head/6Oo8jjq8MIbCaTfeHVhmoEWEJkY.js">\n  </script>\n  <script>\n   document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );\n  </script>\n  <script>\n   (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Iroha_Tamaki","wgTitle":"Iroha Tamaki","wgCurRevisionId":89916,"wgRevisionId":89916,"wgArticleId":16584,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Characters","Magical girls"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","
# ...

# %%
bullet_points = soup.find_all('li')
print(bullet_points)
# Out:
# [<li class="toclevel-1 tocsection-1"><a href="#General_Info"><span class="tocnumber">1</span> <span class="toctext">General Info</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Physical_features"><span class="tocnumber">1.1</span> <span class="toctext">Physical features</span></a></li>
# <li class="toclevel-2 tocsection-3"><a href="#Other"><span class="tocnumber">1.2</span> <span class="toctext">Other</span></a></li>
# </ul>
# ...

# %%
bullet_points[45]
# Out:
# <li><a href="/Magia_Record_Story_April_Fool%27s_2018" title="Magia Record Story April Fool's 2018">April Fool's 2018</a></li>

# %%
len(bullet_points)
# Out:
# 142

# %%
# 26 - 39 General Info
bullet_points[39]
Iroha = {
    "Name": "Iroha Tamaki",
    "Age:": str(bullet_points[26]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "Birthday": str(bullet_points[27]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "Height": str(bullet_points[28]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "EyeColor": str(bullet_points[29]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "HairColor": str(bullet_points[30]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "Hometown": str(bullet_points[31]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "SoulGem": str(bullet_points[32]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "Weapon": str(bullet_points[33]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "Wish": str(bullet_points[34]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "Ability": str(bullet_points[35]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "Witch": str(bullet_points[36]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "Pronoun": str(bullet_points[37]).strip("<li>").strip("</li>").strip("<b>").strip("</b>"),
    "Relatives": str(bullet_points[38]).strip("<li>").strip("</li>").strip("<b>").strip("</b>").strip('<a href="/Ui_Tamaki" title="Ui Tamaki">').strip('</a>'),
    "School": str(bullet_points[39]).strip("<li>").strip("</li>").strip("<b>").strip("</b>")
}

# %%
print(Iroha)
# Out:
# {'Name': 'Iroha Tamaki', 'Age:': 'Age: </b>15', 'Birthday': 'Birthday: </b>August 22', 'Height': 'Height:</b> 156cm', 'EyeColor': 'Eye colour:</b> Pink', 'HairColor': 'Hair colour:</b> Pink', 'Hometown': 'Origins:</b> Takarazaki city', 'SoulGem': 'Soul Gem:</b> Pink circle (belt at her throat)', 'Weapon': 'Weapon:</b> <a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">Crossbow</a', 'Wish': 'Wish:</b> "Please, cure my younger sister’s illness…! Make Ui healthy again! For that…I, will do anything…!!"', 'Ability': 'Ability:</b> Healing', 'Witch': 'Witch form:</b> Giovanna', 'Pronoun': 'Japanese pronoun:</b> watashi<span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'Relatives': 'Known relatives:</b> <a href="/Ui_Tamaki" title="Ui Tamaki">Ui (little sister)</a>, unnamed mother and', 'School': 'School:</b> Transferred to Kamihama City University Affiliated School, 9th grade'}

# %%
para = soup.find_all('p')
print(para)
# Out:
# [<p>English: <a class="external text" href="https://twitter.com/KiraBuckland/status/1225173841317511168" rel="nofollow">Kira Buckland</a><br/>
# Russian: Anastasiya Portnaya
# </p>, <p><b>Iroha Tamaki</b> is the main character of the 2017 mobile game <a href="/Puella_Magi_Madoka_Magica_Side_Story:_Magia_Record" title="Puella Magi Madoka Magica Side Story: Magia Record">Puella Magi Madoka Magica Side Story: Magia Record</a>
# </p>, <p><br/>
# </p>, <p>Iroha came to Kamihama to investigate strange dreams she was having. Kind-hearted, she tends to worry too much about others. She's not up on the latest trends and isn't good with her phone. Usually reserved, she can be a fighter when it matters most.
# ...

# %%
para[5]
# Out:
# <p>The Doppel of silence. Its form is a calling bird. The master of this emotion is aware of her Doppel’s pitiful form, but is unable to view it directly. This Doppel speaks of nothing; it wraps everything that it doesn’t want to hear in cloth, and squeezes it to pieces. It is forever searching for something that can fill the empty hole in its chest. Despite how desperately it needed to call out for someone, this cowardly Doppel is afraid to take a direct look at the reality that it hid away with cloth, and its ears remain covered in silence.
# </p>

# %%
iroha_para = str(para[5])
iroha_para = iroha_para.strip("<p>")
iroha_para = iroha_para.strip("</p>")
iroha_para = iroha_para.rstrip()
print(iroha_para)
# Out:
# The Doppel of silence. Its form is a calling bird. The master of this emotion is aware of her Doppel’s pitiful form, but is unable to view it directly. This Doppel speaks of nothing; it wraps everything that it doesn’t want to hear in cloth, and squeezes it to pieces. It is forever searching for something that can fill the empty hole in its chest. Despite how desperately it needed to call out for someone, this cowardly Doppel is afraid to take a direct look at the reality that it hid away with cloth, and its ears remain covered in silence.

# %%
table_data = soup.find_all('td')
print(table_data)
# Out:
# [<td colspan="2" style="text-align: center"><a class="image" href="/File:Iroha_Character.png"><img alt="Iroha Character.png" height="499" src="//images.puella-magi.net/thumb/2/2a/Iroha_Character.png/300px-Iroha_Character.png?20170513234558" srcset="//images.puella-magi.net/2/2a/Iroha_Character.png?20170513234558 1.5x" width="300"/></a>
# </td>, <td style="text-align: left; background-color: #eef; font-weight: bold;">Japanese Name
# </td>, <td style="text-align: left; {{{datastyle}}}">(環 いろは) Tamaki Iroha
# </td>, <td style="text-align: left; background-color: #eef; font-weight: bold;">Voiced by
# </td>, <td style="text-align: left; {{{datastyle}}}">Japanese: <a class="external text" href="https://ja.wikipedia.org/wiki/%E9%BA%BB%E5%80%89%E3%82%82%E3%82%82" rel="nofollow">Momo Asakura</a>
# <p>English: <a class="external text" href="https://twitter.com/KiraBuckland/status/1225173841317511168" rel="nofollow">Kira Buckland</a><br/>
# Russian: Anastasiya Portnaya
# </p>
# ...

# %%
# table_data[8] through
# Headers no1 8, 9,10, 11
# Data 12, 13, 14, 15 - 15 is a Link Picture
# Headers no2 16, 17, 18, 19
# initial 20, 21, 22, 23
initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 1* 24, 25, 26, 27
one_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
one_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
one_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 2* 28, 29, 30, 31
two_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 3* 32, 33, 34, 35
three_star_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 36, 37, 38, 39
four_star_hp = str(table_data[37]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[38]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[39]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 5* [40], [41], [42], [43]
five_star_hp = str(table_data[41]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_atk = str(table_data[42]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_def = str(table_data[43]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# Max SE 44, 45, 46, 47
se_hp = str(table_data[45]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_atk = str(table_data[46]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_def = str(table_data[47]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
print(initial_hp)
# Out:
# 3068

# %%
# data 48 through 52 is disks
# if condition on alt attribute to determine what type of data to put where

disk_one = str(table_data[48])
disk_two = str(table_data[49])
disk_three = str(table_data[50])
disk_four = str(table_data[51])
disk_five = str(table_data[52])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)
# Out:
# ['Accel', 'Accel', 'Blast', 'Blast', 'Charge']

# %%
# table_data 53 through 57 are Connect Info
connect_one_star = str(table_data[53])
connect_two_star = str(table_data[54])
connect_three_star = str(table_data[55])
connect_four_star = str(table_data[56])
connect_five_star = str(table_data[57])

connect_one_star = connect_one_star.replace('</td>', '')
connect_one_star = connect_one_star.replace('<td style="width:100%;">', '')
connect_one_star = connect_one_star.rstrip()
print(connect_one_star)

connect_two_star = connect_two_star.replace('</td>', '')
connect_two_star = connect_two_star.replace('<td style="width:100%;">', '')
connect_two_star = connect_two_star.rstrip()
print(connect_two_star)

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

connect_five_star = connect_five_star.replace('</td>', '')
connect_five_star = connect_five_star.replace('<td style="width:100%;">', '')
connect_five_star = connect_five_star.rstrip()
print(connect_five_star)
# Out:
# ★1: HP Recovery [I]
# ★2: HP Recovery [III]
# ★3: HP Recovery [V]
# ★4: HP Recovery [VII] &amp; Restore MP to Yachiyo
# ★5: HP Recovery [VIII] &amp; &amp; Attack UP [VI] &amp; Restore MP to Yachiyo

# %%
# table_data 58 through 62 are Magia Info
table_data[58]
magia_one_star = str(table_data[58])
magia_two_star = str(table_data[59])
magia_three_star = str(table_data[60])
magia_four_star = str(table_data[61])
magia_five_star = str(table_data[62])

magia_one_star = magia_one_star.replace('</td>', '')
magia_one_star = magia_one_star.replace('<td style="width:100%;">', '')
magia_one_star = magia_one_star.rstrip()
print(magia_one_star)

magia_two_star = magia_two_star.replace('</td>', '')
magia_two_star = magia_two_star.replace('<td style="width:100%;">', '')
magia_two_star = magia_two_star.rstrip()
print(magia_two_star)

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

magia_five_star = magia_five_star.replace('</td>', '')
magia_five_star = magia_five_star.replace('<td style="width:100%;">', '')
magia_five_star = magia_five_star.rstrip()
print(magia_five_star)
# Out:
# ★1: Damage to all enemies [I] &amp; Revive Ally
# ★2: Damage to all enemies [I] &amp; Revive Ally
# ★3: Damage to all enemies [II] &amp; Revive Ally
# ★4: Damage to all enemies [IV] &amp; Revive Ally
# ★5: Damage to all enemies [VI] &amp; Revive Ally &amp; HP Restore (All)

# %%
# table_data 63 is Doppel Info
table_data[63]
doppel_info = str(table_data[63])
doppel_info = doppel_info.replace('<td style="width:100%;">', '')
doppel_info = doppel_info.replace('</td>', '')
doppel_info = doppel_info.rstrip()
print(doppel_info)
# Out:
# Damage to all enemies [VIII] &amp; Revive Ally &amp; HP Restore (All) &amp; Remove All Negative Effects

# %%
table_head = soup.find_all('th')
print(table_head)
# Out:
# [<th colspan="2" style="text-align: center; background-color: #ccf; font-size: 120%; font-weight: bold;">Iroha Tamaki
# </th>, <th style="text-align:center; padding:10px;">Stats, Connect, Magia Data
# </th>, <th colspan="5"><b>Disks</b>
# </th>, <th colspan="5"><b>Connect:</b> <i>We're Together, We'll Be Fine</i>
# </th>, <th colspan="5"><b>Magia:</b> <i>Strada · Futuro</i>
# </th>, <th colspan="5">Doppel:<b> <i>Giovanna</i></b>
# </th>, <th style="text-align:center; padding:10px;">Spirit Enhancement Data
# </th>, <th colspan="7"><b>Max Stat Bonuses</b>
# </th>, <th colspan="5">Spirit Enhancement
# </th>]

# %%
# table_head[3] is connect
# table_head[4] is magia
# table_head[5] is dopple
connect = str(table_head[3])
magia = str(table_head[4])
doppel = str(table_head[5])
print(magia)
print(doppel)
# Out:
# <th colspan="5"><b>Magia:</b> <i>Strada · Futuro</i>
# </th>
# <th colspan="5">Doppel:<b> <i>Giovanna</i></b>
# </th>

# %%
connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)
# Out:
# Connect: We're Together, We'll Be Fine

# %%
magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)
# Out:
# Magia: Strada · Futuro

# %%
doppel = doppel.strip('<th colspan="5">')
doppel = doppel.strip('b>')
doppel = doppel.replace('<b>', '')
doppel = doppel.replace('</b>', '')
doppel = doppel.replace('<i>', '')
doppel = doppel.replace('</i>', '')
doppel = doppel.strip('</')
doppel = doppel.rstrip()
print(doppel)
# Out:
# Doppel: Giovanna

# %%
# Out:
# [('Age: 15',), ('Birthday: August 22',), ('Height: 156cm',), ('Eye colour: Pink',), ('Hair colour: Pink',), ('Origins: Takarazaki city',), ('Soul Gem: Pink circle (belt at her throat)',), ('Weapon: <a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">Crossbow</a',), ('Wish: "Please cure my younger sister’s illness…! Make Ui healthy again! For that…I will do anything…!!"',), ('Ability: Healing',), ('Witch form: Giovanna',), ('Japanese pronoun: watashi<span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span',), ('Known relatives: Ui (little sister) unnamed mother and father',), 'School: Transferred to Kamihama City University Affiliated School 9th grade']

# %%
Age = str(bullet_points[26]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Birthday = str(bullet_points[27]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Birthday)
Height = str(bullet_points[28]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[29]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[30]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[31]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[32]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[33]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[34]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[35]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[36]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Witch)
Pronoun = str(bullet_points[37]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
Relatives = str(bullet_points[38]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('<a href="/Ui_Tamaki" title="Ui Tamaki">', '').replace('</a>', '').replace(',', '')
print(Relatives)
School = str(bullet_points[39]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)
# Out:
# Age: 15
# Birthday: August 22
# Height: 156cm
# Eye colour: Pink
# Hair colour: Pink
# Origins: Takarazaki city
# Soul Gem: Pink circle (belt at her throat)
# Weapon: Crossbow
# Wish: "Please cure my younger sister’s illness…! Make Ui healthy again! For that…I will do anything…!!"
# Ability: Healing
# Witch form: Giovanna
# Japanese pronoun: watashi<span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span
# Known relatives: Ui (little sister) unnamed mother and father
# School: Transferred to Kamihama City University Affiliated School 9th grade

# %%
Iroha = {
    "Name": "Iroha Tamaki",
    "Age": Age,
    "Birthday": Birthday,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "Relatives": Relatives,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "One_Star": {
            "HP": one_star_hp,
            "ATK": one_star_atk,
            "DEF": one_star_def         
        },
        "Two_Star": {
            "HP": two_star_hp,
            "ATK": two_star_atk,
            "DEF": two_star_def 
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "Five_Star": {
            "HP": five_star_hp,
            "ATK": five_star_atk,
            "DEF": five_star_def        
        },
        "SE": {
            "HP": se_hp,
            "ATK": se_atk,
            "DEF":  se_def          
        }
    },
    "Connect": {
        "Name": connect,
        "One_Star": connect_one_star,
        "Two_Star": connect_two_star,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star,
        "Five_Star": connect_five_star
    },
    "Magia": {
        "Name": magia,
        "One_Star": magia_one_star,
        "Two_Star": magia_two_star,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star,
        "Five_Star": magia_five_star
    },
    "Doppel": {
        "Name": doppel,
        "Desc": iroha_para,
        "Ability": doppel_info,
    }
}

# %%
print(Iroha)
# Out:
# {'Name': 'Iroha Tamaki', 'Age': 'Age: 15', 'Birthday': 'Birthday: August 22', 'EyeColor': 'Eye colour: Pink', 'HairColor': 'Hair colour: Pink', 'Hometown': 'Origins: Takarazaki city', 'SoulGem': 'Soul Gem: Pink circle (belt at her throat)', 'Weapon': 'Weapon: Crossbow', 'Wish': 'Wish: "Please cure my younger sister’s illness…! Make Ui healthy again! For that…I will do anything…!!"', 'Ability': 'Ability: Healing', 'Witch': 'Witch form: Giovanna', 'Pronoun': 'Japanese pronoun: watashi<span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'Relatives': 'Known relatives: Ui (little sister) unnamed mother and father', 'School': 'School: Transferred to Kamihama City University Affiliated School 9th grade', 'Disks': ['Accel', 'Accel', 'Blast', 'Blast', 'Charge'], 'Stats': {'Initial': {'HP': '3068', 'ATK': '878', 'DEF': '1157'}, 'One_Star': {'HP': '9204', 'ATK': '2634', 'DEF': '3471'}, 'Two_Star': {'HP': '10633', 'ATK': '3033', 'DEF': '4016'}, 'Three_Sta
# ...

# %%
iroha_json = json.dumps(Iroha)
print(iroha_json)
# Out:
# {"Name": "Iroha Tamaki", "Age": "Age: 15", "Birthday": "Birthday: August 22", "EyeColor": "Eye colour: Pink", "HairColor": "Hair colour: Pink", "Hometown": "Origins: Takarazaki city", "SoulGem": "Soul Gem: Pink circle (belt at her throat)", "Weapon": "Weapon: Crossbow", "Wish": "Wish: \"Please cure my younger sister\u2019s illness\u2026! Make Ui healthy again! For that\u2026I will do anything\u2026!!\"", "Ability": "Ability: Healing", "Witch": "Witch form: Giovanna", "Pronoun": "Japanese pronoun: watashi<span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u79c1</span>)</span", "Relatives": "Known relatives: Ui (little sister) unnamed mother and father", "School": "School: Transferred to Kamihama City University Affiliated School 9th grade", "Disks": ["Accel", "Accel", "Blast", "Blast", "Charge"], "Stats": {"Initial": {"HP": "3068", "ATK": "878", "DEF": "1157"}, "One_Star": {"HP": "9204", "ATK": "2634", "DEF": "3471"}, "Two_Star": {"HP": "10633", "ATK": "
# ...

# %%
with open('iroha.json', 'w') as json_file:
  json.dump(iroha_json, json_file)
