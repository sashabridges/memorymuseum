# %%
https://wiki.puella-magi.net/Konoha_Shizumi
https://wiki.puella-magi.net/Hazuki_Yusa
https://wiki.puella-magi.net/Ayame_Mikuri

# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import json
import requests

# %%
query_url = "https://wiki.puella-magi.net/Konoha_Shizumi"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[14])
print(bullet_points[25])

para = soup.find_all('p')
para = str(para[2])
para = para.strip("<p>")
para = para.strip("</p>")
para = para.replace('<a class="external text" href="https://en.wikipedia.org/wiki/Sansukumi-ken" rel="nofollow">', '')
para = para.replace('</a>', '')
para = para.replace('<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]', '')
para = para.replace('</sup', '')
para = para.replace('>', '')
para = para.rstrip()
print(para)
# Out:
# <li><b>Age:</b> 17</li>
# <li><b>School:</b> Sankyoin Educational Academy, Eleventh Grade</li>
# The Doppel of retribution. Its form is a fox.
# The master of this emotion performs acts of vengeance against those she hates, using a variety of magic attacks. This Doppel is part of the Fox Trinity and represents retaliation. It is skilled in magic and can use will-o'-wisps to confuse its enemies. So long as their master's grudge burns on, not even water can extinguish them. The master will lose her ability to think logically while using the Doppel; instead, she will act purely on instinct and perform extraordinary acrobatics.

# %%
table_data = soup.find_all('td')

initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

four_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 5* [40], [41], [42], [43]
five_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(four_star_hp, four_star_atk, four_star_def)
print(five_star_hp, five_star_atk, five_star_def)

disk_one = str(table_data[32])
disk_two = str(table_data[33])
disk_three = str(table_data[34])
disk_four = str(table_data[35])
disk_five = str(table_data[36])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)

# table_data 49 through 52 are Connect Info
connect_four_star = str(table_data[37])
connect_five_star = str(table_data[38])

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

connect_five_star = connect_five_star.replace('</td>', '')
connect_five_star = connect_five_star.replace('<td style="width:100%;">', '')
connect_five_star = connect_five_star.rstrip()
print(connect_five_star)

# table_data 53 through 56 are Magia Info
magia_four_star = str(table_data[39])
magia_five_star = str(table_data[40])

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

magia_five_star = magia_five_star.replace('</td>', '')
magia_five_star = magia_five_star.replace('<td style="width:100%;">', '')
magia_five_star = magia_five_star.rstrip()
print(magia_five_star)

doppel_info = str(table_data[41])
doppel_info = doppel_info.replace('<td style="width:100%;">', '')
doppel_info = doppel_info.replace('</td>', '')
doppel_info = doppel_info.rstrip()
print(doppel_info)

table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
doppel = str(table_head[5])
print(magia)
print(doppel)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.replace('<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)

doppel = doppel.strip('<th colspan="5">')
doppel = doppel.strip('b>')
doppel = doppel.replace('<b>', '')
doppel = doppel.replace('</b>', '')
doppel = doppel.replace('<i>', '')
doppel = doppel.replace('</i>', '')
doppel = doppel.replace('<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>', '')
doppel = doppel.strip('</')
doppel = doppel.rstrip()
print(doppel)
# Out:
# 5898 1684 1911
# 21386 6661 6978
# 26940 8388 8793
# ['Accel', 'Accel', 'Blast', 'Blast', 'Charge']
# ★4: HP Recovery [VI] &amp; Accele MP Gain UP [VII] &amp; Attack Up [VII]
# ★5: HP Recovery [VIII] &amp; Accele MP Gain UP [IX] &amp; Attack Up [IX]
# ★4: Damage All Enemies [IV] &amp; HP Regeneration (All / 3 T)
# ★5: Damage All Enemies [VI] &amp; HP Regeneration (All / 3 T) &amp; Ignore Counter (All / 3 T)
# Damage All Enemies [VIII] &amp; HP Regeneration (All / 3 T) &amp; Ignore Counter (All / 3 T)
# <th colspan="5"><b>Magia:</b> <i>Butterfly Tempest</i>
# </th>
# <th colspan="5"><b>Doppel: <i>Tagori</i></b>
# </th>
# Connect: Allow Me to Handle This
# Magia: Butterfly Tempest
# Doppel: Tagori

# %%
Age = str(bullet_points[14]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[15]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[16]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Witch)
Pronoun = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[25]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)

Konoha = {
    "Name": "Konoha Shizumi",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "Five_Star": {
            "HP": five_star_hp,
            "ATK": five_star_atk,
            "DEF": five_star_def        
        }
    },
    "Connect": {
        "Name": connect,
        "Four_Star": connect_four_star,
        "Five_Star": connect_five_star
    },
    "Magia": {
        "Name": magia,
        "Four_Star": magia_four_star,
        "Five_Star": magia_five_star
    },
    "Doppel": {
        "Name": doppel,
        "Desc": para,
        "Ability": doppel_info,
    }
}

print(Konoha)
# Out:
# Age: 17
# Height: 165cm
# Eye colour: Purple
# Hair colour: Grey
# Origins: Sankyo Ward
# Soul Gem: Purple 5-point Azalea flower (back of left hand)
# Weapon: Double-bladed staff
# Wish: To "erase the main cause that tried to demolish Tsuzuji's House" (Tsuzuji's House meaning Azalea's House is the orphanage Konoha grew up in).
# Ability: Generate fog and illusions around others
# Witch form: Tagor
# Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span
# School: Sankyoin Educational Academy Eleventh Grade
# {'Name': 'Konoha Shizumi', 'Age': 'Age: 17', 'EyeColor': 'Eye colour: Purple', 'HairColor': 'Hair colour: Grey', 'Hometown': 'Origins: Sankyo Ward', 'SoulGem': 'Soul Gem: Purple 5-point Azalea flower (back of left hand)', 'Weapon': 'Weapon: Double-bladed staff', 'Wish': 'Wish: To "erase the main cause that tried to demolish Tsuzuji\'s House" (Tsuzuji\'s House meaning Azalea\'s House is the orphanage Konoha grew up in).', 'Ability': 'Ability: Generate fog and illusions around others', 'Witch': 'Witch form: Tagor', 'Pronoun': 'Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'School': 'School: Sankyoin Educational Academy Eleventh Grade', 'Disks': ['Accel', 'Accel', 'Blast', 'Blast', 'Charge'], 'Stats': {'Initial': {'HP': '5898', 'ATK': '1684', 'DEF': '1911'}, 'Four_Star': {'HP': '21386', 'ATK': '6661', 'DEF': '6978'}, 'Five_Star': {'HP': '26940', 'ATK': '8388', 'DEF': '8793'}}, 'Connect': {'Name': 'Connect: Allow Me to Handle This', 'Four_Star': '★4: HP Recovery [VI] &amp; Accele MP Gain UP [VII] &amp; Attack Up [VII]', 'Five_Star': '★5: HP Recovery [VIII] &amp; Accele MP Gain UP [IX] &amp; Attack Up [IX]'}, 'Magia': {'Name': 'Magia: Butterfly Tempest', 'Four_Star': '★4: Damage All Enemies [IV] &amp; HP Regeneration (All / 3 T)', 'Five_Star': '★5: Damage All Enemies [VI] &amp; HP Regeneration (All / 3 T) &amp; Ignore Counter (All / 3 T)'}, 'Doppel': {'Name': 'Doppel: Tagori', 'Desc': "The Doppel of retribution. Its form is a fox.\nThe master of this emotion performs acts of vengeance against those she hates, using a variety of magic attacks. This Doppel is part of the Fox Trinity and represents retaliation. It is skilled in magic and can use will-o'-wisps to confuse its enemies. So long as their master's grudge burns on, not even water can extinguish them. The master will lose her ability to think logically while using the Doppel; instead, she will act purely on instinct and perform extraordinary acrobatics.", 'Ability': 'Damage All Enemies [VIII] &amp; HP Regeneration (All / 3 T) &amp; Ignore Counter (All / 3 T)'}}

# %%
girl_json = json.dumps(Konoha)
print(girl_json)

with open('konoha.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Konoha Shizumi", "Age": "Age: 17", "EyeColor": "Eye colour: Purple", "HairColor": "Hair colour: Grey", "Hometown": "Origins: Sankyo Ward", "SoulGem": "Soul Gem: Purple 5-point Azalea flower (back of left hand)", "Weapon": "Weapon: Double-bladed staff", "Wish": "Wish: To \"erase the main cause that tried to demolish Tsuzuji's House\" (Tsuzuji's House meaning Azalea's House is the orphanage Konoha grew up in).", "Ability": "Ability: Generate fog and illusions around others", "Witch": "Witch form: Tagor", "Pronoun": "Japanese pronoun: <i>watashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u79c1</span>)</span", "School": "School: Sankyoin Educational Academy Eleventh Grade", "Disks": ["Accel", "Accel", "Blast", "Blast", "Charge"], "Stats": {"Initial": {"HP": "5898", "ATK": "1684", "DEF": "1911"}, "Four_Star": {"HP": "21386", "ATK": "6661", "DEF": "6978"}, "Five_Star": {"HP": "26940", "ATK": "8388", "DEF": "8793"}}, "Connect": {"Name": "Connect: Allow Me to Handle This", "Four_Star": "\u26054: HP Recovery [VI] &amp; Accele MP Gain UP [VII] &amp; Attack Up [VII]", "Five_Star": "\u26055: HP Recovery [VIII] &amp; Accele MP Gain UP [IX] &amp; Attack Up [IX]"}, "Magia": {"Name": "Magia: Butterfly Tempest", "Four_Star": "\u26054: Damage All Enemies [IV] &amp; HP Regeneration (All / 3 T)", "Five_Star": "\u26055: Damage All Enemies [VI] &amp; HP Regeneration (All / 3 T) &amp; Ignore Counter (All / 3 T)"}, "Doppel": {"Name": "Doppel: Tagori", "Desc": "The Doppel of retribution. Its form is a fox.\nThe master of this emotion performs acts of vengeance against those she hates, using a variety of magic attacks. This Doppel is part of the Fox Trinity and represents retaliation. It is skilled in magic and can use will-o'-wisps to confuse its enemies. So long as their master's grudge burns on, not even water can extinguish them. The master will lose her ability to think logically while using the Doppel; instead, she will act purely on instinct and perform extraordinary acrobatics.", "Ability": "Damage All Enemies [VIII] &amp; HP Regeneration (All / 3 T) &amp; Ignore Counter (All / 3 T)"}}

# %%
query_url = "https://wiki.puella-magi.net/Hazuki_Yusa"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[13])
print(bullet_points[24])
# Out:
# <li><b>Age:</b> 15</li>
# <li><b>School:</b> Sankyoin Educational Academy, Ninth Grade</li>

# %%
table_data = soup.find_all('td')

initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

four_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 5* [40], [41], [42], [43]
five_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(four_star_hp, four_star_atk, four_star_def)
print(five_star_hp, five_star_atk, five_star_def)

disk_one = str(table_data[32])
disk_two = str(table_data[33])
disk_three = str(table_data[34])
disk_four = str(table_data[35])
disk_five = str(table_data[36])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)

# table_data 49 through 52 are Connect Info
connect_four_star = str(table_data[37])
connect_five_star = str(table_data[38])

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

connect_five_star = connect_five_star.replace('</td>', '')
connect_five_star = connect_five_star.replace('<td style="width:100%;">', '')
connect_five_star = connect_five_star.rstrip()
print(connect_five_star)

# table_data 53 through 56 are Magia Info
magia_four_star = str(table_data[39])
magia_five_star = str(table_data[40])

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

magia_five_star = magia_five_star.replace('</td>', '')
magia_five_star = magia_five_star.replace('<td style="width:100%;">', '')
magia_five_star = magia_five_star.rstrip()
print(magia_five_star)

table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
print(magia)
print(doppel)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.replace('<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)
# Out:
# 4785 1373 1315
# 16039 4767 4376
# 20844 6204 5684
# ['Accel', 'Blast', 'Blast', 'Charge', 'Charge']
# ★3: Damage UP [VI] &amp; Guaranteed Curse Edge
# ★4: Damage UP [VIII] &amp; Guaranteed Curse Edge
# ★3: Damage All Enemies [III] &amp; Enemy Attack DOWN (All / 3 T)
# ★3: Damage All Enemies [III] &amp; Enemy Attack DOWN (All / 3 T) &amp; Guaranteed Curse Edge (All / 1 T)
# <th colspan="5"><b>Magia:</b> <i>Thunder Torrent</i>
# </th>
# Doppel: Tagori
# Connect: Perfect! Now Let's Finish It Off!
# Magia: Thunder Torrent

# %%
Age = str(bullet_points[13]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[14]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[15]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[16]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Witch)
Pronoun = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)

Hazuki = {
    "Name": "Hazuki Yusa",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Three_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "Four_Star": {
            "HP": five_star_hp,
            "ATK": five_star_atk,
            "DEF": five_star_def        
        }
    },
    "Connect": {
        "Name": connect,
        "Three_Star": connect_four_star,
        "Four_Star": connect_five_star
    },
    "Magia": {
        "Name": magia,
        "Three_Star": magia_four_star,
        "Four_Star": magia_five_star
    }
}

print(Hazuki)
# Out:
# Age: 15
# Height: 175cm
# Eye colour: Yellow
# Hair colour: Yellow
# Origins: Sankyo Ward
# Soul Gem: Yellow 5-point Azalea flower (under her chest)
# Weapon: Two staffs each with two axe-like blades on the same side
# Wish: "I want to erase the memories I lived in." (referring to Azalea's House the orphanage Hazuki grew up in with her magical girl partners).
# Ability: Body Scan (Instantly understand the strong and weak points)
# Witch form:</
# Japanese pronoun: <i>atashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">アタシ</span>)</span
# School: Sankyoin Educational Academy Ninth Grade
# {'Name': 'Hazuki Yusa', 'Age': 'Age: 15', 'EyeColor': 'Eye colour: Yellow', 'HairColor': 'Hair colour: Yellow', 'Hometown': 'Origins: Sankyo Ward', 'SoulGem': 'Soul Gem: Yellow 5-point Azalea flower (under her chest)', 'Weapon': 'Weapon: Two staffs each with two axe-like blades on the same side', 'Wish': 'Wish: "I want to erase the memories I lived in." (referring to Azalea\'s House the orphanage Hazuki grew up in with her magical girl partners).', 'Ability': 'Ability: Body Scan (Instantly understand the strong and weak points)', 'Witch': 'Witch form:</', 'Pronoun': 'Japanese pronoun: <i>atashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">アタシ</span>)</span', 'School': 'School: Sankyoin Educational Academy Ninth Grade', 'Disks': ['Accel', 'Blast', 'Blast', 'Charge', 'Charge'], 'Stats': {'Initial': {'HP': '4785', 'ATK': '1373', 'DEF': '1315'}, 'Three_Star': {'HP': '16039', 'ATK': '4767', 'DEF': '4376'}, 'Four_Star': {'HP': '20844', 'ATK': '6204', 'DEF': '5684'}}, 'Connect': {'Name': "Connect: Perfect! Now Let's Finish It Off!", 'Three_Star': '★3: Damage UP [VI] &amp; Guaranteed Curse Edge', 'Four_Star': '★4: Damage UP [VIII] &amp; Guaranteed Curse Edge'}, 'Magia': {'Name': 'Magia: Thunder Torrent', 'Three_Star': '★3: Damage All Enemies [III] &amp; Enemy Attack DOWN (All / 3 T)', 'Four_Star': '★3: Damage All Enemies [III] &amp; Enemy Attack DOWN (All / 3 T) &amp; Guaranteed Curse Edge (All / 1 T)'}}

# %%
girl_json = json.dumps(Hazuki)
print(girl_json)

with open('hazuki.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Hazuki Yusa", "Age": "Age: 15", "EyeColor": "Eye colour: Yellow", "HairColor": "Hair colour: Yellow", "Hometown": "Origins: Sankyo Ward", "SoulGem": "Soul Gem: Yellow 5-point Azalea flower (under her chest)", "Weapon": "Weapon: Two staffs each with two axe-like blades on the same side", "Wish": "Wish: \"I want to erase the memories I lived in.\" (referring to Azalea's House the orphanage Hazuki grew up in with her magical girl partners).", "Ability": "Ability: Body Scan (Instantly understand the strong and weak points)", "Witch": "Witch form:</", "Pronoun": "Japanese pronoun: <i>atashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u30a2\u30bf\u30b7</span>)</span", "School": "School: Sankyoin Educational Academy Ninth Grade", "Disks": ["Accel", "Blast", "Blast", "Charge", "Charge"], "Stats": {"Initial": {"HP": "4785", "ATK": "1373", "DEF": "1315"}, "Three_Star": {"HP": "16039", "ATK": "4767", "DEF": "4376"}, "Four_Star": {"HP": "20844", "ATK": "6204", "DEF": "5684"}}, "Connect": {"Name": "Connect: Perfect! Now Let's Finish It Off!", "Three_Star": "\u26053: Damage UP [VI] &amp; Guaranteed Curse Edge", "Four_Star": "\u26054: Damage UP [VIII] &amp; Guaranteed Curse Edge"}, "Magia": {"Name": "Magia: Thunder Torrent", "Three_Star": "\u26053: Damage All Enemies [III] &amp; Enemy Attack DOWN (All / 3 T)", "Four_Star": "\u26053: Damage All Enemies [III] &amp; Enemy Attack DOWN (All / 3 T) &amp; Guaranteed Curse Edge (All / 1 T)"}}

# %%
query_url = "https://wiki.puella-magi.net/Ayame_Mikuri"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[13])
print(bullet_points[24])
# Out:
# <li><b>Age:</b> 13</li>
# <li><b>School:</b> Sankyoin Educational Academy, Seventh Grade</li>

# %%
table_data = soup.find_all('td')

initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 2* 28, 29, 30, 31
two_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 3* 32, 33, 34, 35
three_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 36, 37, 38, 39
four_star_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(two_star_hp, two_star_atk, two_star_def)
print(three_star_hp, three_star_atk, three_star_def)
print(four_star_hp, four_star_atk, four_star_def)
# Out:
# 3122 1300 1006
# 9990 4160 3219
# 12658 5270 4080
# 16657 6929 5367

# %%
disk_one = str(table_data[36])
disk_two = str(table_data[37])
disk_three = str(table_data[38])
disk_four = str(table_data[39])
disk_five = str(table_data[40])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)
# Out:
# ['Accel', 'Blast', 'Charge', 'Charge', 'Charge']

# %%
# table_data 49 through 52 are Connect Info
connect_two_star = str(table_data[41])
connect_three_star = str(table_data[42])
connect_four_star = str(table_data[43])

connect_two_star = connect_two_star.replace('</td>', '')
connect_two_star = connect_two_star.replace('<td style="width:100%;">', '')
connect_two_star = connect_two_star.rstrip()
print(connect_two_star)

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

# table_data 53 through 56 are Magia Info

magia_two_star = str(table_data[44])
magia_three_star = str(table_data[45])
magia_four_star = str(table_data[46])

magia_two_star = magia_two_star.replace('</td>', '')
magia_two_star = magia_two_star.replace('<td style="width:100%;">', '')
magia_two_star = magia_two_star.rstrip()
print(magia_two_star)

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)
# Out:
# ★2: Charged Damage UP [III] &amp; Guaranteed Burn Edge
# ★3: Charged Damage UP [V] &amp; Guaranteed Burn Edge
# ★4: Charged Damage UP [VII] &amp; Guaranteed Burn Edge
# ★2: Damage One Enemy [I] &amp; Burn (1 T)
# ★3: Damage One Enemy [III] &amp; Burn (1 T)
# ★4: Damage One Enemy [V] &amp; Burn (1 T) &amp; Attack UP (All / 3 T)

# %%
table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
print(magia)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.replace('<sup class="reference" id="cite_ref-1">', '')
magia = magia.replace('<a href="#cite_note-1">[1]</a></sup>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)
# Out:
# <th colspan="5"><b>Magia:</b> <i>Unidentified Flying Fire</i>
# </th>
# Connect: I'll Show Ya What I've Got!
# Magia: Unidentified Flying Fire

# %%
Age = str(bullet_points[13]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[14]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[15]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[16]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '').replace('</', '')
print(Witch)
Pronoun = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)
# Out:
# Age: 13
# Height: 145cm
# Eye colour: Green
# Hair colour: Pink
# Origins: Sankyo Ward
# Soul Gem: Green 5-pointed Azalea flower (beneath neck)
# Weapon: <a class="external text" href="https://en.wikipedia.org/wiki/Axe" rel="nofollow">Bow-like axe
# Wish: For "Tsuzuji's House to continue to exist indefinitely" (Tsuzuji's House meaning Azalea's House is the orphanage Ayame grew up in).
# Ability: Invincibility (For a short time defensive power will improve dramatically)
# Witch form:
# Japanese pronoun: <i>achishi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">あちし</span>)</span
# School: Sankyoin Educational Academy Seventh Grade

# %%
Ayame = {
    "Name": "Ayame Mikuri",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Two_Star": {
            "HP": two_star_hp,
            "ATK": two_star_atk,
            "DEF": two_star_def 
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        }
    },
    "Connect": {
        "Name": connect,
        "Two_Star": connect_two_star,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star
    },
    "Magia": {
        "Name": magia,
        "Two_Star": magia_two_star,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star
    },
    "Doppel": {
        "Name": ""
    }
}

print(Ayame)
# Out:
# {'Name': 'Ayame Mikuri', 'Age': 'Age: 13', 'EyeColor': 'Eye colour: Green', 'HairColor': 'Hair colour: Pink', 'Hometown': 'Origins: Sankyo Ward', 'SoulGem': 'Soul Gem: Green 5-pointed Azalea flower (beneath neck)', 'Weapon': 'Weapon: <a class="external text" href="https://en.wikipedia.org/wiki/Axe" rel="nofollow">Bow-like axe', 'Wish': 'Wish: For "Tsuzuji\'s House to continue to exist indefinitely" (Tsuzuji\'s House meaning Azalea\'s House is the orphanage Ayame grew up in).', 'Ability': 'Ability: Invincibility (For a short time defensive power will improve dramatically)', 'Witch': 'Witch form:', 'Pronoun': 'Japanese pronoun: <i>achishi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">あちし</span>)</span', 'School': 'School: Sankyoin Educational Academy Seventh Grade', 'Disks': ['Accel', 'Blast', 'Charge', 'Charge', 'Charge'], 'Stats': {'Initial': {'HP': '3122', 'ATK': '1300', 'DEF': '1006'}, 'Two_Star': {'HP': '9990', 'ATK': '4160', 'DEF': '3219'}, 'Three_Star': {'HP': '12658', 'ATK': '5270', 'DEF': '4080'}, 'Four_Star': {'HP': '16657', 'ATK': '6929', 'DEF': '5367'}}, 'Connect': {'Name': "Connect: I'll Show Ya What I've Got!", 'Two_Star': '★2: Charged Damage UP [III] &amp; Guaranteed Burn Edge', 'Three_Star': '★3: Charged Damage UP [V] &amp; Guaranteed Burn Edge', 'Four_Star': '★4: Charged Damage UP [VII] &amp; Guaranteed Burn Edge'}, 'Magia': {'Name': 'Magia: Unidentified Flying Fire', 'Two_Star': '★2: Damage One Enemy [I] &amp; Burn (1 T)', 'Three_Star': '★3: Damage One Enemy [III] &amp; Burn (1 T)', 'Four_Star': '★4: Damage One Enemy [V] &amp; Burn (1 T) &amp; Attack UP (All / 3 T)'}, 'Doppel': {'Name': ''}}

# %%
girl_json = json.dumps(Ayame)
print(girl_json)

with open('ayame.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Ayame Mikuri", "Age": "Age: 13", "EyeColor": "Eye colour: Green", "HairColor": "Hair colour: Pink", "Hometown": "Origins: Sankyo Ward", "SoulGem": "Soul Gem: Green 5-pointed Azalea flower (beneath neck)", "Weapon": "Weapon: <a class=\"external text\" href=\"https://en.wikipedia.org/wiki/Axe\" rel=\"nofollow\">Bow-like axe", "Wish": "Wish: For \"Tsuzuji's House to continue to exist indefinitely\" (Tsuzuji's House meaning Azalea's House is the orphanage Ayame grew up in).", "Ability": "Ability: Invincibility (For a short time defensive power will improve dramatically)", "Witch": "Witch form:", "Pronoun": "Japanese pronoun: <i>achishi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u3042\u3061\u3057</span>)</span", "School": "School: Sankyoin Educational Academy Seventh Grade", "Disks": ["Accel", "Blast", "Charge", "Charge", "Charge"], "Stats": {"Initial": {"HP": "3122", "ATK": "1300", "DEF": "1006"}, "Two_Star": {"HP": "9990", "ATK": "4160", "DEF": "3219"}, "Three_Star": {"HP": "12658", "ATK": "5270", "DEF": "4080"}, "Four_Star": {"HP": "16657", "ATK": "6929", "DEF": "5367"}}, "Connect": {"Name": "Connect: I'll Show Ya What I've Got!", "Two_Star": "\u26052: Charged Damage UP [III] &amp; Guaranteed Burn Edge", "Three_Star": "\u26053: Charged Damage UP [V] &amp; Guaranteed Burn Edge", "Four_Star": "\u26054: Charged Damage UP [VII] &amp; Guaranteed Burn Edge"}, "Magia": {"Name": "Magia: Unidentified Flying Fire", "Two_Star": "\u26052: Damage One Enemy [I] &amp; Burn (1 T)", "Three_Star": "\u26053: Damage One Enemy [III] &amp; Burn (1 T)", "Four_Star": "\u26054: Damage One Enemy [V] &amp; Burn (1 T) &amp; Attack UP (All / 3 T)"}, "Doppel": {"Name": ""}}
