# %%
https://wiki.puella-magi.net/Ultimate_Madoka_in_Magia_Record
https://wiki.puella-magi.net/Homura_Akemi_in_Magia_Record

# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import json
import requests

# %%
query_url = "https://wiki.puella-magi.net/Ultimate_Madoka_in_Magia_Record"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[12])
print(bullet_points[22])
# Out:
# <li><b>Age:</b> -</li>
# <li><b>School:</b> -</li>

# %%
table_data = soup.find_all('td')

initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

four_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 5* [40], [41], [42], [43]
five_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(four_star_hp, four_star_atk, four_star_def)
print(five_star_hp, five_star_atk, five_star_def)

disk_one = str(table_data[32])
disk_two = str(table_data[33])
disk_three = str(table_data[34])
disk_four = str(table_data[35])
disk_five = str(table_data[36])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)

# table_data 49 through 52 are Connect Info
connect_four_star = str(table_data[37])
connect_five_star = str(table_data[38])

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

connect_five_star = connect_five_star.replace('</td>', '')
connect_five_star = connect_five_star.replace('<td style="width:100%;">', '')
connect_five_star = connect_five_star.rstrip()
print(connect_five_star)

# table_data 53 through 56 are Magia Info
magia_four_star = str(table_data[39])
magia_five_star = str(table_data[40])

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

magia_five_star = magia_five_star.replace('</td>', '')
magia_five_star = magia_five_star.replace('<td style="width:100%;">', '')
magia_five_star = magia_five_star.rstrip()
print(magia_five_star)

doppel_info = str(table_data[41])
doppel_info = doppel_info.replace('<td style="width:100%;">', '')
doppel_info = doppel_info.replace('</td>', '')
doppel_info = doppel_info.rstrip()
print(doppel_info)

table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
doppel = str(table_head[5])
print(magia)
print(doppel)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.replace('<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)

doppel = doppel.strip('<th colspan="5">')
doppel = doppel.strip('b>')
doppel = doppel.replace('<b>', '')
doppel = doppel.replace('</b>', '')
doppel = doppel.replace('<i>', '')
doppel = doppel.replace('</i>', '')
doppel = doppel.replace('<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>', '')
doppel = doppel.strip('</')
doppel = doppel.rstrip()
print(doppel)
# Out:
# 6467 1979 1728
# 23113 7227 6265
# 29143 9114 7906
# ['Accel', 'Accel', 'Blast', 'Blast', 'Charge']
# ★4: Damage UP [VII] &amp; Status Resistance UP &amp; Chance to Survive &amp; Remove Status Ailments
# ★5: Damage UP [IX] &amp; Status Resistance UP &amp; Guaranteed Survive &amp; Remove Status Ailments
# ★4: Damage to all enemies [V] &amp; Attack UP &amp; All disk effects UP &amp; Damage Cut (All / 3 T)
# ★5: Damage to all enemies [VII] &amp; Attack UP &amp; All disk effects UP &amp; Damage Cut (All / 3 T)
# Damage to all enemies [IX] &amp; Attack UP &amp; All disk effects UP &amp; Damage Cut (All / 3 T)
# <th colspan="5"><b>Magia 1:</b> <i>Nothing to despair, ever</i>
# </th>
# <th colspan="5"><b>Magia 2:</b> <i>Everyone will be with me forever</i><sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>
# </th>
# Connect: Sorry to keep you waiting
# Magia 1: Nothing to despair, ever
# Magia 2: Everyone will be with me forever

# %%
Age = str(bullet_points[12]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[13]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[14]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[15]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[16]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Pronoun = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)

Madokami = {
    "Name": "Ultimate Madoka",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "Five_Star": {
            "HP": five_star_hp,
            "ATK": five_star_atk,
            "DEF": five_star_def        
        }
    },
    "Connect": {
        "Name": connect,
        "Four_Star": connect_four_star,
        "Five_Star": connect_five_star
    },
    "Magia": {
        "Name": magia,
        "Four_Star": magia_four_star,
        "Five_Star": magia_five_star
    },
    "Doppel": {
        "Name": doppel,
        "Ability": doppel_info,
    }
}

print(Madokami)
# Out:
# Age: -
# Height: -
# Eye colour: Gold
# Hair colour: Pink
# Origins: -
# Soul gem: -
# Weapon: -
# Wish: <span class="inline-spoilers"> "I want to erase all witches before they are even born. I will erase every single witch in every universe past and future with my own hands...I don't care what you call it. All those magical girls who held onto their hopes and fought against witches I don't want to see them cry. I want them to stay smiling until the end. If any rule or law stands in my way I will destroy it. I will rewrite it. That is my prayer. That is my wish. Now grant it Incubator!"</span
# Ability: -
# Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">わたし</span>)</span
# School: -
# {'Name': 'Ultimate Madoka', 'Age': 'Age: -', 'EyeColor': 'Eye colour: Gold', 'HairColor': 'Hair colour: Pink', 'Hometown': 'Origins: -', 'SoulGem': 'Soul gem: -', 'Weapon': 'Weapon: -', 'Wish': 'Wish: <span class="inline-spoilers"> "I want to erase all witches before they are even born. I will erase every single witch in every universe past and future with my own hands...I don\'t care what you call it. All those magical girls who held onto their hopes and fought against witches I don\'t want to see them cry. I want them to stay smiling until the end. If any rule or law stands in my way I will destroy it. I will rewrite it. That is my prayer. That is my wish. Now grant it Incubator!"</span', 'Ability': 'Ability: -', 'Pronoun': 'Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">わたし</span>)</span', 'School': 'School: -', 'Disks': ['Accel', 'Accel', 'Blast', 'Blast', 'Charge'], 'Stats': {'Initial': {'HP': '6467', 'ATK': '1979', 'DEF': '1728'}, 'Four_Star': {'HP': '23113', 'ATK': '7227', 'DEF': '6265'}, 'Five_Star': {'HP': '29143', 'ATK': '9114', 'DEF': '7906'}}, 'Connect': {'Name': 'Connect: Sorry to keep you waiting', 'Four_Star': '★4: Damage UP [VII] &amp; Status Resistance UP &amp; Chance to Survive &amp; Remove Status Ailments', 'Five_Star': '★5: Damage UP [IX] &amp; Status Resistance UP &amp; Guaranteed Survive &amp; Remove Status Ailments'}, 'Magia': {'Name': 'Magia 1: Nothing to despair, ever', 'Four_Star': '★4: Damage to all enemies [V] &amp; Attack UP &amp; All disk effects UP &amp; Damage Cut (All / 3 T)', 'Five_Star': '★5: Damage to all enemies [VII] &amp; Attack UP &amp; All disk effects UP &amp; Damage Cut (All / 3 T)'}, 'Doppel': {'Name': 'Magia 2: Everyone will be with me forever', 'Ability': 'Damage to all enemies [IX] &amp; Attack UP &amp; All disk effects UP &amp; Damage Cut (All / 3 T)'}}

# %%
girl_json = json.dumps(Madokami)
print(girl_json)

with open('madokami.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Ultimate Madoka", "Age": "Age: -", "EyeColor": "Eye colour: Gold", "HairColor": "Hair colour: Pink", "Hometown": "Origins: -", "SoulGem": "Soul gem: -", "Weapon": "Weapon: -", "Wish": "Wish: <span class=\"inline-spoilers\"> \"I want to erase all witches before they are even born. I will erase every single witch in every universe past and future with my own hands...I don't care what you call it. All those magical girls who held onto their hopes and fought against witches I don't want to see them cry. I want them to stay smiling until the end. If any rule or law stands in my way I will destroy it. I will rewrite it. That is my prayer. That is my wish. Now grant it Incubator!\"</span", "Ability": "Ability: -", "Pronoun": "Japanese pronoun: <i>watashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u308f\u305f\u3057</span>)</span", "School": "School: -", "Disks": ["Accel", "Accel", "Blast", "Blast", "Charge"], "Stats": {"Initial": {"HP": "6467", "ATK": "1979", "DEF": "1728"}, "Four_Star": {"HP": "23113", "ATK": "7227", "DEF": "6265"}, "Five_Star": {"HP": "29143", "ATK": "9114", "DEF": "7906"}}, "Connect": {"Name": "Connect: Sorry to keep you waiting", "Four_Star": "\u26054: Damage UP [VII] &amp; Status Resistance UP &amp; Chance to Survive &amp; Remove Status Ailments", "Five_Star": "\u26055: Damage UP [IX] &amp; Status Resistance UP &amp; Guaranteed Survive &amp; Remove Status Ailments"}, "Magia": {"Name": "Magia 1: Nothing to despair, ever", "Four_Star": "\u26054: Damage to all enemies [V] &amp; Attack UP &amp; All disk effects UP &amp; Damage Cut (All / 3 T)", "Five_Star": "\u26055: Damage to all enemies [VII] &amp; Attack UP &amp; All disk effects UP &amp; Damage Cut (All / 3 T)"}, "Doppel": {"Name": "Magia 2: Everyone will be with me forever", "Ability": "Damage to all enemies [IX] &amp; Attack UP &amp; All disk effects UP &amp; Damage Cut (All / 3 T)"}}

# %%
query_url = "https://wiki.puella-magi.net/Homura_Akemi_in_Magia_Record"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[12])
print(bullet_points[23])
# Out:
# <li><b>Age:</b> 13-14 (estimated)</li>
# <li><b>School:</b> Attended a Christian/Catholic school in Tokyo before transferring to Mitakihara Middle School, 8th grade</li>

# %%
table_data = soup.find_all('td')

# initial 20, 21, 22, 23
initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 33, 34, 35
four_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 5* 37, 38, 39
five_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# SE
se_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(four_star_hp, four_star_atk, four_star_def)
print(five_star_hp, five_star_atk, five_star_def)
print(se_hp, se_atk, se_def)

disk_one = str(table_data[36])
disk_two = str(table_data[37])
disk_three = str(table_data[38])
disk_four = str(table_data[39])
disk_five = str(table_data[40])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)

# table_data 49 through 52 are Connect Info
connect_four_star = str(table_data[41])
connect_five_star = str(table_data[42])

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

connect_five_star = connect_five_star.replace('</td>', '')
connect_five_star = connect_five_star.replace('<td style="width:100%;">', '')
connect_five_star = connect_five_star.rstrip()
print(connect_five_star)

# table_data 53 through 56 are Magia Info

magia_four_star = str(table_data[43])
magia_five_star = str(table_data[44])

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

magia_five_star = magia_five_star.replace('</td>', '')
magia_five_star = magia_five_star.replace('<td style="width:100%;">', '')
magia_five_star = magia_five_star.rstrip()
print(magia_five_star)

doppel_info = str(table_data[45])
doppel_info = doppel_info.replace('<td style="width:100%;">', '')
doppel_info = doppel_info.replace('</td>', '')
doppel_info = doppel_info.rstrip()
print(doppel_info)

table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
doppel = str(table_head[5])
print(magia)
print(doppel)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)

doppel = doppel.strip('<th colspan="5">')
doppel = doppel.strip('b>')
doppel = doppel.replace('<b>', '')
doppel = doppel.replace('</b>', '')
doppel = doppel.replace('<i>', '')
doppel = doppel.replace('</i>', '')
doppel = doppel.strip('</')
doppel = doppel.rstrip()
print(doppel)
# Out:
# 4825 2078 1742
# 16993 7372 6497
# 21411 9294 8208
# 27939 11417 10010
# ['Accel', 'Blast', 'Blast', 'Blast', 'Charge']
# ★4: Attack UP [VII] &amp; Chance to Critical [VII] &amp; Chance to Stun
# ★5: Attack UP [IX] &amp; Chance to Critical [IX] &amp; Chance to Stun
# ★4: Damage to All Enemies [V] &amp; Chance to Stun (All / 1 T) &amp; Chance to Critical (Self / 2 T)
# ★5: Damage to All Enemies [VII] &amp; Chance to Stun (All / 1 T) &amp; Chance to Critical (Self / 2 T)
# Damage to Five Random Enemies [VIII] &amp; Chance to Stun (All / 1 T) &amp; Guaranteed Critical (Self / 2 T)
# <th colspan="5"><b>Magia:</b> <i>Crossfire Missiles</i>
# </th>
# <th colspan="5"><b>Doppel:</b> <i>Homulilly</i>
# </th>
# Connect: That'll be your prey
# Magia: Crossfire Missiles
# Doppel: Homulilly

# %%
Age = str(bullet_points[12]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[13]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '').replace('</a', '').replace('<a class="internal" href="//images.puella-magi.net/e/ec/PN_10.jpg?20111204064051" title="PN 10.jpg">', '')
print(Height)
EyeColor = str(bullet_points[14]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[15]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[16]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '').replace('<span class="inline-spoilers">', '').replace('</span', '')
print(Wish)
Ability = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Witch)
Pronoun = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)

Coolmura = {
    "Name": "Homura Akemi",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "Five_Star": {
            "HP": five_star_hp,
            "ATK": five_star_atk,
            "DEF": five_star_def        
        },
        "SE": {
            "HP": se_hp,
            "ATK": se_atk,
            "DEF":  se_def          
        }
    },
    "Connect": {
        "Name": connect,
        "Four_Star": connect_four_star,
        "Five_Star": connect_five_star
    },
    "Magia": {
        "Name": magia,
        "Four_Star": magia_four_star,
        "Five_Star": magia_five_star
    },
    "Doppel": {
        "Name": doppel,
        "Desc": para,
        "Ability": doppel_info,
    }
}

print(Coolmura)
# Out:
# Age: 13-14 (estimated)
# Height: 155-159cm
# Eye colour: Purple
# Hair colour: Black
# Origins: Mitakihara City
# Soul Gem: Purple Diamond (back of left hand)
# Weapon: Round Shield (storage and timejump device). Homura has been shown using golf club, pipe bombs, IMI Desert Eagle, FN Minimi, Beretta 92FS, Remington 870, Howa Type 89, M26 frag grenades, flashbang grenades, RPG-7, AT-4, C-4 explosives
# Wish:  "I want to redo my first encounter with Kaname-san. But this time instead of her protecting me I want to become strong enough to protect her!"
# Ability: Time manipulation
# Witch form: <a href="/Homulilly" title="Homulilly">Homulilly</a
# Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span
# School: Attended a Christian/Catholic school in Tokyo before transferring to Mitakihara Middle School 8th grade
# {'Name': 'Homura Akemi', 'Age': 'Age: 13-14 (estimated)', 'EyeColor': 'Eye colour: Purple', 'HairColor': 'Hair colour: Black', 'Hometown': 'Origins: Mitakihara City', 'SoulGem': 'Soul Gem: Purple Diamond (back of left hand)', 'Weapon': 'Weapon: Round Shield (storage and timejump device). Homura has been shown using golf club, pipe bombs, IMI Desert Eagle, FN Minimi, Beretta 92FS, Remington 870, Howa Type 89, M26 frag grenades, flashbang grenades, RPG-7, AT-4, C-4 explosives', 'Wish': 'Wish:  "I want to redo my first encounter with Kaname-san. But this time instead of her protecting me I want to become strong enough to protect her!"', 'Ability': 'Ability: Time manipulation', 'Witch': 'Witch form: <a href="/Homulilly" title="Homulilly">Homulilly</a', 'Pronoun': 'Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'School': 'School: Attended a Christian/Catholic school in Tokyo before transferring to Mitakihara Middle School 8th grade', 'Disks': ['Accel', 'Blast', 'Blast', 'Blast', 'Charge'], 'Stats': {'Initial': {'HP': '4825', 'ATK': '2078', 'DEF': '1742'}, 'Four_Star': {'HP': '16993', 'ATK': '7372', 'DEF': '6497'}, 'Five_Star': {'HP': '21411', 'ATK': '9294', 'DEF': '8208'}, 'SE': {'HP': '27939', 'ATK': '11417', 'DEF': '10010'}}, 'Connect': {'Name': "Connect: That'll be your prey", 'Four_Star': '★4: Attack UP [VII] &amp; Chance to Critical [VII] &amp; Chance to Stun', 'Five_Star': '★5: Attack UP [IX] &amp; Chance to Critical [IX] &amp; Chance to Stun'}, 'Magia': {'Name': 'Magia: Crossfire Missiles', 'Four_Star': '★4: Damage to All Enemies [V] &amp; Chance to Stun (All / 1 T) &amp; Chance to Critical (Self / 2 T)', 'Five_Star': '★5: Damage to All Enemies [VII] &amp; Chance to Stun (All / 1 T) &amp; Chance to Critical (Self / 2 T)'}, 'Doppel': {'Name': 'Doppel: Homulilly', 'Desc': 'Homura looks on as <a href="/Madoka_Kaname" title="Madoka Kaname">Madoka Kaname</a> makes her contract with Kyubey and becomes <a href="/Ultimate_Madoka_in_Magia_Record" title="Ultimate Madoka in Magia Record">Ultimate Madoka</a>. Homura then finds herself in an star-filled cosmos as the universe rewrites itself according to Madoka\'s new rules. Madoka thanks Homura for all she did trying to protect her and then bids Homura goodbye.', 'Ability': 'Damage to Five Random Enemies [VIII] &amp; Chance to Stun (All / 1 T) &amp; Guaranteed Critical (Self / 2 T)'}}

# %%
girl_json = json.dumps(Coolmura)
print(girl_json)

with open('coolmura.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Homura Akemi", "Age": "Age: 13-14 (estimated)", "EyeColor": "Eye colour: Purple", "HairColor": "Hair colour: Black", "Hometown": "Origins: Mitakihara City", "SoulGem": "Soul Gem: Purple Diamond (back of left hand)", "Weapon": "Weapon: Round Shield (storage and timejump device). Homura has been shown using golf club, pipe bombs, IMI Desert Eagle, FN Minimi, Beretta 92FS, Remington 870, Howa Type 89, M26 frag grenades, flashbang grenades, RPG-7, AT-4, C-4 explosives", "Wish": "Wish:  \"I want to redo my first encounter with Kaname-san. But this time instead of her protecting me I want to become strong enough to protect her!\"", "Ability": "Ability: Time manipulation", "Witch": "Witch form: <a href=\"/Homulilly\" title=\"Homulilly\">Homulilly</a", "Pronoun": "Japanese pronoun: <i>watashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u79c1</span>)</span", "School": "School: Attended a Christian/Catholic school in Tokyo before transferring to Mitakihara Middle School 8th grade", "Disks": ["Accel", "Blast", "Blast", "Blast", "Charge"], "Stats": {"Initial": {"HP": "4825", "ATK": "2078", "DEF": "1742"}, "Four_Star": {"HP": "16993", "ATK": "7372", "DEF": "6497"}, "Five_Star": {"HP": "21411", "ATK": "9294", "DEF": "8208"}, "SE": {"HP": "27939", "ATK": "11417", "DEF": "10010"}}, "Connect": {"Name": "Connect: That'll be your prey", "Four_Star": "\u26054: Attack UP [VII] &amp; Chance to Critical [VII] &amp; Chance to Stun", "Five_Star": "\u26055: Attack UP [IX] &amp; Chance to Critical [IX] &amp; Chance to Stun"}, "Magia": {"Name": "Magia: Crossfire Missiles", "Four_Star": "\u26054: Damage to All Enemies [V] &amp; Chance to Stun (All / 1 T) &amp; Chance to Critical (Self / 2 T)", "Five_Star": "\u26055: Damage to All Enemies [VII] &amp; Chance to Stun (All / 1 T) &amp; Chance to Critical (Self / 2 T)"}, "Doppel": {"Name": "Doppel: Homulilly", "Desc": "Homura looks on as <a href=\"/Madoka_Kaname\" title=\"Madoka Kaname\">Madoka Kaname</a> makes her contract with Kyubey and becomes <a href=\"/Ultimate_Madoka_in_Magia_Record\" title=\"Ultimate Madoka in Magia Record\">Ultimate Madoka</a>. Homura then finds herself in an star-filled cosmos as the universe rewrites itself according to Madoka's new rules. Madoka thanks Homura for all she did trying to protect her and then bids Homura goodbye.", "Ability": "Damage to Five Random Enemies [VIII] &amp; Chance to Stun (All / 1 T) &amp; Guaranteed Critical (Self / 2 T)"}}
