# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import json
import requests

query_url = "https://wiki.puella-magi.net/Manaka_Kurumi"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[17])
print(bullet_points[28])

para = soup.find_all('p')
para = str(para[3])
para = para.strip("<p>")
para = para.strip("</p>")
para = para.rstrip()
print(para)
# Out:
# <li><b>Age:</b> 14</li>
# <li><b>School:</b> Mizuna Girls' School, Eighth Grade</li>
# The doppel of customer-gathering. Its form is propane. The master of this emotion is displeased with this Doppel, which can only produce poisonous meals due to the toxins that seep from its body. This Doppel uses the burners on the ends of its jellyfish-like tentacles to cook absolutely any ingredients into delicious poison meals, and forces its customers to enjoy a long stay in the seats that furnish its spherical glass head. The meals cooked by this witch have minds of their own, and are proactive in making surprise visits to customers’ stomachs, which makes it possible to enjoy one’s meal just by sitting in place. Incidentally, the meals may be poisonous, but they taste very good. But despite their taste, they make abundant use of suspiciously-produced ingredients, including mystery meat from unknown sources, moaning vegetables, and fruit that walks around on its own.

# %%
table_data = soup.find_all('td')

# table_data[8] through
# Headers no1 8, 9,10, 11
# Data 12, 13, 14, 15 - 15 is a Link Picture
# Headers no2 16, 17, 18, 19
# initial 20, 21, 22, 23
initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 2* 25, 26, 27
two_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 3* 29, 30, 31
three_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 33, 34, 35
four_star_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 5* 37, 38, 39
five_star_hp = str(table_data[37]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_atk = str(table_data[38]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_def = str(table_data[39]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# Max SE 41, 42, 43
se_hp = str(table_data[41]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_atk = str(table_data[42]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_def = str(table_data[43]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
print(initial_hp, initial_atk, initial_def)
print(two_star_hp, two_star_atk, two_star_def)
print(three_star_hp, three_star_atk, three_star_def)
print(four_star_hp, four_star_atk, four_star_def)
print(five_star_hp, five_star_atk, five_star_def)
print(se_hp, se_atk, se_def)
# Out:
# 3303 953 1240
# 10569 3049 3968
# 13396 3865 5032
# 17625 5086 6624
# 21860 6316 8212
# 24949 7811 10014

# %%
# data 44 through 48 is disks
# if condition on alt attribute to determine what type of data to put where

disk_one = str(table_data[44])
disk_two = str(table_data[45])
disk_three = str(table_data[46])
disk_four = str(table_data[47])
disk_five = str(table_data[48])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)
# Out:
# ['Accel', 'Accel', 'Blast', 'Charge', 'Charge']

# %%
# table_data 49 through 52 are Connect Info
connect_two_star = str(table_data[49])
connect_three_star = str(table_data[50])
connect_four_star = str(table_data[51])
connect_five_star = str(table_data[52])

connect_two_star = connect_two_star.replace('</td>', '')
connect_two_star = connect_two_star.replace('<td style="width:100%;">', '')
connect_two_star = connect_two_star.rstrip()
print(connect_two_star)

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

connect_five_star = connect_five_star.replace('</td>', '')
connect_five_star = connect_five_star.replace('<td style="width:100%;">', '')
connect_five_star = connect_five_star.rstrip()
print(connect_five_star)

# table_data 53 through 56 are Magia Info
table_data[58]
magia_two_star = str(table_data[53])
magia_three_star = str(table_data[54])
magia_four_star = str(table_data[55])
magia_five_star = str(table_data[56])

magia_two_star = magia_two_star.replace('</td>', '')
magia_two_star = magia_two_star.replace('<td style="width:100%;">', '')
magia_two_star = magia_two_star.rstrip()
print(magia_two_star)

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

magia_five_star = magia_five_star.replace('</td>', '')
magia_five_star = magia_five_star.replace('<td style="width:100%;">', '')
magia_five_star = magia_five_star.rstrip()
print(magia_five_star)
# Out:
# ★2: HP Restore [III] &amp; Attack UP [III]
# ★3: HP Restore [V] &amp; Attack UP [V]
# ★4: HP Restore [VII] &amp; Attack UP [VII]
# ★5: HP Restore [IX] &amp; Attack UP [IX]
# ★2: Damage in a Vertical Line [I] &amp; HP Restore (All)
# ★3: Damage in a Vertical Line [II] &amp; HP Restore (All)
# ★4: Damage in a Vertical Line [IV] &amp; HP Restore (All) &amp; Attack UP (All / 3 T)
# ★5: Damage in a Vertical Line [VI] &amp; HP Restore (All) &amp; Attack UP (All / 3 T)

# %%
# table_data 57 is Doppel Info
table_data[57]
doppel_info = str(table_data[57])
doppel_info = doppel_info.replace('<td style="width:100%;">', '')
doppel_info = doppel_info.replace('</td>', '')
doppel_info = doppel_info.rstrip()
print(doppel_info)

table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
doppel = str(table_head[5])
print(magia)
print(doppel)
# Out:
# Damage in a Vertical Line [VIII] &amp; HP Restore (All) &amp; Attack UP (All / 3 T)
# <th colspan="5"><b>Magia:</b> <i>Complete Spices</i>
# </th>
# <th colspan="5"><b>Doppel:</b> <i>Carmela</i>
# </th>

# %%
connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.replace('<sup class="reference" id="cite_ref-1">', '')
magia = magia.replace('<a href="#cite_note-1">[1]</a></su', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)

doppel = doppel.strip('<th colspan="5">')
doppel = doppel.strip('b>')
doppel = doppel.replace('<b>', '')
doppel = doppel.replace('</b>', '')
doppel = doppel.replace('<i>', '')
doppel = doppel.replace('</i>', '')
doppel = doppel.strip('</')
doppel = doppel.rstrip()
print(doppel)
# Out:
# Connect: I'll Bring out the flavor!
# Magia: Complete Spices
# Doppel: Carmela

# %%
Age = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[25]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[26]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Witch)
Pronoun = str(bullet_points[27]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[28]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)
# Out:
# Age: 14
# Height: 154cm
# Eye colour: Dark orange
# Hair colour: Reddish orange
# Origins: Hokuyo Ward
# Soul Gem: Orange carrot (rim of chef's hat)
# Weapon: <a class="external text" href="https://en.wikipedia.org/wiki/Frying_pan" rel="nofollow">Frying pan
# Wish: "Chance! I want a chance! Give me the chance to spread our restaurant’s flavors!"
# Ability: Propagation (Advertising ability. The aftermath damage of an attack is spread to its surroundings.)
# Witch form: Carmela
# Japanese pronoun: <i>Manaka</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">まなか</span>)</span
# School: Mizuna Girls' School Eighth Grade

# %%
Manaka = {
    "Name": "Manaka Kurumi",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Two_Star": {
            "HP": two_star_hp,
            "ATK": two_star_atk,
            "DEF": two_star_def 
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "Five_Star": {
            "HP": five_star_hp,
            "ATK": five_star_atk,
            "DEF": five_star_def        
        },
        "SE": {
            "HP": se_hp,
            "ATK": se_atk,
            "DEF":  se_def          
        }
    },
    "Connect": {
        "Name": connect,
        "Two_Star": connect_two_star,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star,
        "Five_Star": connect_five_star
    },
    "Magia": {
        "Name": magia,
        "Two_Star": magia_two_star,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star,
        "Five_Star": magia_five_star
    },
    "Doppel": {
        "Name": doppel,
        "Desc": para,
        "Ability": doppel_info,
    }
}

print(Manaka)
# Out:
# {'Name': 'Manaka Kurumi', 'Age': 'Age: 14', 'EyeColor': 'Eye colour: Dark orange', 'HairColor': 'Hair colour: Reddish orange', 'Hometown': 'Origins: Hokuyo Ward', 'SoulGem': "Soul Gem: Orange carrot (rim of chef's hat)", 'Weapon': 'Weapon: <a class="external text" href="https://en.wikipedia.org/wiki/Frying_pan" rel="nofollow">Frying pan', 'Wish': 'Wish: "Chance! I want a chance! Give me the chance to spread our restaurant’s flavors!"', 'Ability': 'Ability: Propagation (Advertising ability. The aftermath damage of an attack is spread to its surroundings.)', 'Witch': 'Witch form: Carmela', 'Pronoun': 'Japanese pronoun: <i>Manaka</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">まなか</span>)</span', 'School': "School: Mizuna Girls' School Eighth Grade", 'Disks': ['Accel', 'Accel', 'Blast', 'Charge', 'Charge'], 'Stats': {'Initial': {'HP': '3303', 'ATK': '953', 'DEF': '1240'}, 'Two_Star': {'HP': '10569', 'ATK': '3049', 'DEF': '3968'}, 'Three_Star': {'HP': '13396', 'ATK': '3865', 'DEF': '5032'}, 'Four_Star': {'HP': '17625', 'ATK': '5086', 'DEF': '6624'}, 'Five_Star': {'HP': '21860', 'ATK': '6316', 'DEF': '8212'}, 'SE': {'HP': '24949', 'ATK': '7811', 'DEF': '10014'}}, 'Connect': {'Name': "Connect: I'll Bring out the flavor!", 'Two_Star': '★2: HP Restore [III] &amp; Attack UP [III]', 'Three_Star': '★3: HP Restore [V] &amp; Attack UP [V]', 'Four_Star': '★4: HP Restore [VII] &amp; Attack UP [VII]', 'Five_Star': '★5: HP Restore [IX] &amp; Attack UP [IX]'}, 'Magia': {'Name': 'Magia: Complete Spices', 'Two_Star': '★2: Damage in a Vertical Line [I] &amp; HP Restore (All)', 'Three_Star': '★3: Damage in a Vertical Line [II] &amp; HP Restore (All)', 'Four_Star': '★4: Damage in a Vertical Line [IV] &amp; HP Restore (All) &amp; Attack UP (All / 3 T)', 'Five_Star': '★5: Damage in a Vertical Line [VI] &amp; HP Restore (All) &amp; Attack UP (All / 3 T)'}, 'Doppel': {'Name': 'Doppel: Carmela', 'Desc': 'The doppel of customer-gathering. Its form is propane. The master of this emotion is displeased with this Doppel, which can only produce poisonous meals due to the toxins that seep from its body. This Doppel uses the burners on the ends of its jellyfish-like tentacles to cook absolutely any ingredients into delicious poison meals, and forces its customers to enjoy a long stay in the seats that furnish its spherical glass head. The meals cooked by this witch have minds of their own, and are proactive in making surprise visits to customers’ stomachs, which makes it possible to enjoy one’s meal just by sitting in place. Incidentally, the meals may be poisonous, but they taste very good. But despite their taste, they make abundant use of suspiciously-produced ingredients, including mystery meat from unknown sources, moaning vegetables, and fruit that walks around on its own.', 'Ability': 'Damage in a Vertical Line [VIII] &amp; HP Restore (All) &amp; Attack UP (All / 3 T)'}}

# %%
girl_json = json.dumps(Manaka)
print(girl_json)

with open('manaka.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Manaka Kurumi", "Age": "Age: 14", "EyeColor": "Eye colour: Dark orange", "HairColor": "Hair colour: Reddish orange", "Hometown": "Origins: Hokuyo Ward", "SoulGem": "Soul Gem: Orange carrot (rim of chef's hat)", "Weapon": "Weapon: <a class=\"external text\" href=\"https://en.wikipedia.org/wiki/Frying_pan\" rel=\"nofollow\">Frying pan", "Wish": "Wish: \"Chance! I want a chance! Give me the chance to spread our restaurant\u2019s flavors!\"", "Ability": "Ability: Propagation (Advertising ability. The aftermath damage of an attack is spread to its surroundings.)", "Witch": "Witch form: Carmela", "Pronoun": "Japanese pronoun: <i>Manaka</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u307e\u306a\u304b</span>)</span", "School": "School: Mizuna Girls' School Eighth Grade", "Disks": ["Accel", "Accel", "Blast", "Charge", "Charge"], "Stats": {"Initial": {"HP": "3303", "ATK": "953", "DEF": "1240"}, "Two_Star": {"HP": "10569", "ATK": "3049", "DEF": "3968"}, "Three_Star": {"HP": "13396", "ATK": "3865", "DEF": "5032"}, "Four_Star": {"HP": "17625", "ATK": "5086", "DEF": "6624"}, "Five_Star": {"HP": "21860", "ATK": "6316", "DEF": "8212"}, "SE": {"HP": "24949", "ATK": "7811", "DEF": "10014"}}, "Connect": {"Name": "Connect: I'll Bring out the flavor!", "Two_Star": "\u26052: HP Restore [III] &amp; Attack UP [III]", "Three_Star": "\u26053: HP Restore [V] &amp; Attack UP [V]", "Four_Star": "\u26054: HP Restore [VII] &amp; Attack UP [VII]", "Five_Star": "\u26055: HP Restore [IX] &amp; Attack UP [IX]"}, "Magia": {"Name": "Magia: Complete Spices", "Two_Star": "\u26052: Damage in a Vertical Line [I] &amp; HP Restore (All)", "Three_Star": "\u26053: Damage in a Vertical Line [II] &amp; HP Restore (All)", "Four_Star": "\u26054: Damage in a Vertical Line [IV] &amp; HP Restore (All) &amp; Attack UP (All / 3 T)", "Five_Star": "\u26055: Damage in a Vertical Line [VI] &amp; HP Restore (All) &amp; Attack UP (All / 3 T)"}, "Doppel": {"Name": "Doppel: Carmela", "Desc": "The doppel of customer-gathering. Its form is propane. The master of this emotion is displeased with this Doppel, which can only produce poisonous meals due to the toxins that seep from its body. This Doppel uses the burners on the ends of its jellyfish-like tentacles to cook absolutely any ingredients into delicious poison meals, and forces its customers to enjoy a long stay in the seats that furnish its spherical glass head. The meals cooked by this witch have minds of their own, and are proactive in making surprise visits to customers\u2019 stomachs, which makes it possible to enjoy one\u2019s meal just by sitting in place. Incidentally, the meals may be poisonous, but they taste very good. But despite their taste, they make abundant use of suspiciously-produced ingredients, including mystery meat from unknown sources, moaning vegetables, and fruit that walks around on its own.", "Ability": "Damage in a Vertical Line [VIII] &amp; HP Restore (All) &amp; Attack UP (All / 3 T)"}}

# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import json
import requests

query_url = "https://wiki.puella-magi.net/Ria_Ami"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[13])
print(bullet_points[24])
# Out:
# <li><b>Age:</b> 17</li>
# <li><b>School:</b> Mizuna Girls' School, Eleventh Grade</li>

# %%
table_data = soup.find_all('td')

initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 3* 32, 33, 34, 35
three_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 36, 37, 38, 39
four_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# Max SE 44, 45, 46, 47
se_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(three_star_hp, three_star_atk, three_star_def)
print(four_star_hp, four_star_atk, four_star_def)
print(se_hp, se_atk, se_def)
# Out:
# 3720 1574 1172
# 12826 5389 3956
# 16685 7012 5142
# 22119 8183 6815

# %%
disk_one = str(table_data[36])
disk_two = str(table_data[37])
disk_three = str(table_data[38])
disk_four = str(table_data[39])
disk_five = str(table_data[40])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)
# Out:
# ['Accel', 'Accel', 'Blast', 'Blast', 'Charge']

# %%
# table_data 49 through 52 are Connect Info
connect_three_star = str(table_data[41])
connect_four_star = str(table_data[42])

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

# table_data 53 through 56 are Magia Info

magia_three_star = str(table_data[43])
magia_four_star = str(table_data[44])

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)
# Out:
# ★3: Damage UP [V] &amp; Guaranteed Dazzle
# ★4: Damage UP [VII] &amp; Guaranteed Dazzle
# ★3: Enhanced Damage to Weak Attribute Single Enemy [IV] &amp; Chance to Charm (Single / 1 T) &amp; Defense DOWN (Single / 3 T)
# ★4: Enhanced Damage to Weak Attribute Single Enemy [IV] &amp; Guaranteed Charm (Single / 1 T) &amp; Defense DOWN (Single / 3 T) &amp; Remove Buffs (Single)

# %%
table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
print(magia)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)
# Out:
# <th colspan="5"><b>Magia:</b> <i>Bella Spina</i>
# </th>
# Connect: Be Energized by My Beauty!
# Magia: Bella Spina

# %%
Age = str(bullet_points[13]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[14]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[15]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[16]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '').replace('</', '')
print(Witch)
Pronoun = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)
# Out:
# Age: 17
# Height: 170cm
# Eye colour: Blue
# Hair colour: Blonde
# Origins: Mizuna Ward
# Soul Gem: Red X-shaped gem (beneath the ribbon at her throat)
# Weapon: Bow and arrow
# Wish: "Turn me... Into a naturally beautiful girl!!"
# Ability: Hiding (Make certain things invisible)
# Witch form:
# Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span
# School: Mizuna Girls' School Eleventh Grade

# %%
Ria = {
    "Name": "Ria Ami",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "SE": {
            "HP": se_hp,
            "ATK": se_atk,
            "DEF":  se_def          
        }
    },
    "Connect": {
        "Name": connect,
        "Two_Star": connect_two_star,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star
    },
    "Magia": {
        "Name": magia,
        "Two_Star": magia_two_star,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star
    },
    "Doppel": {
        "Name": ""
    }
}

print(Ria)
# Out:
# {'Name': 'Ria Ami', 'Age': 'Age: 17', 'EyeColor': 'Eye colour: Blue', 'HairColor': 'Hair colour: Blonde', 'Hometown': 'Origins: Mizuna Ward', 'SoulGem': 'Soul Gem: Red X-shaped gem (beneath the ribbon at her throat)', 'Weapon': 'Weapon: Bow and arrow', 'Wish': 'Wish: "Turn me... Into a naturally beautiful girl!!"', 'Ability': 'Ability: Hiding (Make certain things invisible)', 'Witch': 'Witch form:', 'Pronoun': 'Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'School': "School: Mizuna Girls' School Eleventh Grade", 'Disks': ['Accel', 'Accel', 'Blast', 'Blast', 'Charge'], 'Stats': {'Initial': {'HP': '3720', 'ATK': '1574', 'DEF': '1172'}, 'Three_Star': {'HP': '12826', 'ATK': '5389', 'DEF': '3956'}, 'Four_Star': {'HP': '16685', 'ATK': '7012', 'DEF': '5142'}, 'SE': {'HP': '22119', 'ATK': '8183', 'DEF': '6815'}}, 'Connect': {'Name': 'Connect: Be Energized by My Beauty!', 'Two_Star': '★2: HP Restore [III] &amp; Attack UP [III]', 'Three_Star': '★3: Damage UP [V] &amp; Guaranteed Dazzle', 'Four_Star': '★4: Damage UP [VII] &amp; Guaranteed Dazzle'}, 'Magia': {'Name': 'Magia: Bella Spina', 'Two_Star': '★2: Damage in a Vertical Line [I] &amp; HP Restore (All)', 'Three_Star': '★3: Enhanced Damage to Weak Attribute Single Enemy [IV] &amp; Chance to Charm (Single / 1 T) &amp; Defense DOWN (Single / 3 T)', 'Four_Star': '★4: Enhanced Damage to Weak Attribute Single Enemy [IV] &amp; Guaranteed Charm (Single / 1 T) &amp; Defense DOWN (Single / 3 T) &amp; Remove Buffs (Single)'}, 'Doppel': {'Name': ''}}

# %%
girl_json = json.dumps(Ria)
print(girl_json)

with open('ria.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Ria Ami", "Age": "Age: 17", "EyeColor": "Eye colour: Blue", "HairColor": "Hair colour: Blonde", "Hometown": "Origins: Mizuna Ward", "SoulGem": "Soul Gem: Red X-shaped gem (beneath the ribbon at her throat)", "Weapon": "Weapon: Bow and arrow", "Wish": "Wish: \"Turn me... Into a naturally beautiful girl!!\"", "Ability": "Ability: Hiding (Make certain things invisible)", "Witch": "Witch form:", "Pronoun": "Japanese pronoun: <i>watashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u79c1</span>)</span", "School": "School: Mizuna Girls' School Eleventh Grade", "Disks": ["Accel", "Accel", "Blast", "Blast", "Charge"], "Stats": {"Initial": {"HP": "3720", "ATK": "1574", "DEF": "1172"}, "Three_Star": {"HP": "12826", "ATK": "5389", "DEF": "3956"}, "Four_Star": {"HP": "16685", "ATK": "7012", "DEF": "5142"}, "SE": {"HP": "22119", "ATK": "8183", "DEF": "6815"}}, "Connect": {"Name": "Connect: Be Energized by My Beauty!", "Two_Star": "\u26052: HP Restore [III] &amp; Attack UP [III]", "Three_Star": "\u26053: Damage UP [V] &amp; Guaranteed Dazzle", "Four_Star": "\u26054: Damage UP [VII] &amp; Guaranteed Dazzle"}, "Magia": {"Name": "Magia: Bella Spina", "Two_Star": "\u26052: Damage in a Vertical Line [I] &amp; HP Restore (All)", "Three_Star": "\u26053: Enhanced Damage to Weak Attribute Single Enemy [IV] &amp; Chance to Charm (Single / 1 T) &amp; Defense DOWN (Single / 3 T)", "Four_Star": "\u26054: Enhanced Damage to Weak Attribute Single Enemy [IV] &amp; Guaranteed Charm (Single / 1 T) &amp; Defense DOWN (Single / 3 T) &amp; Remove Buffs (Single)"}, "Doppel": {"Name": ""}}

# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import json
import requests

query_url = "https://wiki.puella-magi.net/Kako_Natsume"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[19])
print(bullet_points[30])

para = soup.find_all('p')
para = str(para[4])
para = para.strip("<p>")
para = para.strip("</p>")
para = para.rstrip()
print(para)
# Out:
# <li><b>Age:</b> 13</li>
# <li><b>School:</b> Kamihama City University Affiliated School, Seventh Grade</li>
# The Doppel of mistaken steps<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>. Its form is cutting.
# The master of this emotion fears her Doppel, as it unreservedly swings its blade to chop up everything in sight– even her precious books. Inwardly, though, she also feels a sense of release that she can’t quite describe.
# Unlike its ever-fearful master, the manifested Doppel chops with its guillotine without ever stopping to think. In addition to its target’s physical body, it shreds any and all magical connections they have.
# This Doppel can only attack physically from very close range, and sometimes slashes at its allies by mistake, so it tends to leave itself open to attack. But the master of this emotion cannot control it, and so can only remain frozen in fear.

# %%
table_data = soup.find_all('td')

# table_data[8] through
# Headers no1 8, 9,10, 11
# Data 12, 13, 14, 15 - 15 is a Link Picture
# Headers no2 16, 17, 18, 19
# initial 20, 21, 22, 23
initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 2* 25, 26, 27
two_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 3* 29, 30, 31
three_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 33, 34, 35
four_star_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 5* 37, 38, 39
five_star_hp = str(table_data[37]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_atk = str(table_data[38]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_def = str(table_data[39]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# Max SE 41, 42, 43
se_hp = str(table_data[41]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_atk = str(table_data[42]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_def = str(table_data[43]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
print(initial_hp, initial_atk, initial_def)
print(two_star_hp, two_star_atk, two_star_def)
print(three_star_hp, three_star_atk, three_star_def)
print(four_star_hp, four_star_atk, four_star_def)
print(five_star_hp, five_star_atk, five_star_def)
print(se_hp, se_atk, se_def)
# Out:
# 3267 977 11229
# 10310 3190 3851
# 13059 4044 4875
# 17179 5325 6413
# 21291 6609 7949
# 25771 7889 9726

# %%
# data 44 through 48 is disks
# if condition on alt attribute to determine what type of data to put where

disk_one = str(table_data[44])
disk_two = str(table_data[45])
disk_three = str(table_data[46])
disk_four = str(table_data[47])
disk_five = str(table_data[48])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)
# Out:
# ['Accel', 'Accel', 'Blast', 'Blast', 'Charge']

# %%
# table_data 49 through 52 are Connect Info
connect_two_star = str(table_data[49])
connect_three_star = str(table_data[50])
connect_four_star = str(table_data[51])
connect_five_star = str(table_data[52])

connect_two_star = connect_two_star.replace('</td>', '')
connect_two_star = connect_two_star.replace('<td style="width:100%;">', '')
connect_two_star = connect_two_star.rstrip()
print(connect_two_star)

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

connect_five_star = connect_five_star.replace('</td>', '')
connect_five_star = connect_five_star.replace('<td style="width:100%;">', '')
connect_five_star = connect_five_star.rstrip()
print(connect_five_star)

# table_data 53 through 56 are Magia Info
table_data[58]
magia_two_star = str(table_data[53])
magia_three_star = str(table_data[54])
magia_four_star = str(table_data[55])
magia_five_star = str(table_data[56])

magia_two_star = magia_two_star.replace('</td>', '')
magia_two_star = magia_two_star.replace('<td style="width:100%;">', '')
magia_two_star = magia_two_star.rstrip()
print(magia_two_star)

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

magia_five_star = magia_five_star.replace('</td>', '')
magia_five_star = magia_five_star.replace('<td style="width:100%;">', '')
magia_five_star = magia_five_star.rstrip()
print(magia_five_star)
# Out:
# ★2: HP Restore [III] &amp; Remove All Status Ailments
# ★3: HP Restore [V] &amp; Remove All Status Ailments
# ★4: HP Restore [VII] &amp; Remove All Status Ailments
# ★5: HP Restore [VIII] &amp; Remove All Status Ailments
# ★2: Damage One Enemy [I] &amp; HP Regeneration (All / 3 T)
# ★3: Damage One Enemy [II] &amp; HP Regeneration (All / 3 T)
# ★4: Damage One Enemy [IV] &amp; HP Regeneration (All / 3 T) &amp; Remove All Status Ailments
# ★5: Damage One Enemy [VI] &amp; HP Regeneration (All / 3 T) &amp; Remove All Status Ailments

# %%
# table_data 57 is Doppel Info
table_data[57]
doppel_info = str(table_data[57])
doppel_info = doppel_info.replace('<td style="width:100%;">', '')
doppel_info = doppel_info.replace('</td>', '')
doppel_info = doppel_info.rstrip()
print(doppel_info)

table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
doppel = str(table_head[5])
print(magia)
print(doppel)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.replace('<sup class="reference" id="cite_ref-1">', '')
magia = magia.replace('<a href="#cite_note-1">[1]</a></su', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)

doppel = doppel.strip('<th colspan="5">')
doppel = doppel.strip('b>')
doppel = doppel.replace('<b>', '')
doppel = doppel.replace('</b>', '')
doppel = doppel.replace('<i>', '')
doppel = doppel.replace('</i>', '')
doppel = doppel.strip('</')
doppel = doppel.rstrip()
print(doppel)
# Out:
# Damage One Enemy [VIII] &amp; Remove Buffs (Target) &amp; Regenerate HP (Allies / 3 T) &amp; Remove Status Ailments (Allies)
# <th colspan="5"><b>Magia:</b> <i>Page of Twinkle Road</i>
# </th>
# <th colspan="5">Doppel:<b> <i>Andreana</i></b>
# </th>
# Connect: On to the Next Page!
# Magia: Page of Twinkle Road
# Doppel: Andreana

# %%
Age = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[25]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[26]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[27]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[28]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Witch)
Pronoun = str(bullet_points[29]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[30]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)

Kako = {
    "Name": "Kako Natsume",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Two_Star": {
            "HP": two_star_hp,
            "ATK": two_star_atk,
            "DEF": two_star_def 
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "Five_Star": {
            "HP": five_star_hp,
            "ATK": five_star_atk,
            "DEF": five_star_def        
        },
        "SE": {
            "HP": se_hp,
            "ATK": se_atk,
            "DEF":  se_def          
        }
    },
    "Connect": {
        "Name": connect,
        "Two_Star": connect_two_star,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star,
        "Five_Star": connect_five_star
    },
    "Magia": {
        "Name": magia,
        "Two_Star": magia_two_star,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star,
        "Five_Star": magia_five_star
    },
    "Doppel": {
        "Name": doppel,
        "Desc": para,
        "Ability": doppel_info,
    }
}

print(Kako)
# Out:
# Age: 13
# Height: 150cm
# Eye colour: Green
# Hair colour: Green
# Origins: Shinsei Ward
# Soul Gem: Green open book (ribbon at her throat)
# Weapon: <a class="external text" href="https://en.wikipedia.org/wiki/Spear" rel="nofollow">Spear> (Tip is squared)
# Wish: "I want to bring back my family's happiness! I want things like they were before... I want Natsume Library back!"
# Ability: Reproduction (Repeat what happened in front of you within the limits of your magic)
# Witch form: Andreana
# Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span
# School: Kamihama City University Affiliated School Seventh Grade
# {'Name': 'Kako Natsume', 'Age': 'Age: 13', 'EyeColor': 'Eye colour: Green', 'HairColor': 'Hair colour: Green', 'Hometown': 'Origins: Shinsei Ward', 'SoulGem': 'Soul Gem: Green open book (ribbon at her throat)', 'Weapon': 'Weapon: <a class="external text" href="https://en.wikipedia.org/wiki/Spear" rel="nofollow">Spear> (Tip is squared)', 'Wish': 'Wish: "I want to bring back my family\'s happiness! I want things like they were before... I want Natsume Library back!"', 'Ability': 'Ability: Reproduction (Repeat what happened in front of you within the limits of your magic)', 'Witch': 'Witch form: Andreana', 'Pronoun': 'Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'School': 'School: Kamihama City University Affiliated School Seventh Grade', 'Disks': ['Accel', 'Accel', 'Blast', 'Blast', 'Charge'], 'Stats': {'Initial': {'HP': '3267', 'ATK': '977', 'DEF': '11229'}, 'Two_Star': {'HP': '10310', 'ATK': '3190', 'DEF': '3851'}, 'Three_Star': {'HP': '13059', 'ATK': '4044', 'DEF': '4875'}, 'Four_Star': {'HP': '17179', 'ATK': '5325', 'DEF': '6413'}, 'Five_Star': {'HP': '21291', 'ATK': '6609', 'DEF': '7949'}, 'SE': {'HP': '25771', 'ATK': '7889', 'DEF': '9726'}}, 'Connect': {'Name': 'Connect: On to the Next Page!', 'Two_Star': '★2: HP Restore [III] &amp; Remove All Status Ailments', 'Three_Star': '★3: HP Restore [V] &amp; Remove All Status Ailments', 'Four_Star': '★4: HP Restore [VII] &amp; Remove All Status Ailments', 'Five_Star': '★5: HP Restore [VIII] &amp; Remove All Status Ailments'}, 'Magia': {'Name': 'Magia: Page of Twinkle Road', 'Two_Star': '★2: Damage One Enemy [I] &amp; HP Regeneration (All / 3 T)', 'Three_Star': '★3: Damage One Enemy [II] &amp; HP Regeneration (All / 3 T)', 'Four_Star': '★4: Damage One Enemy [IV] &amp; HP Regeneration (All / 3 T) &amp; Remove All Status Ailments', 'Five_Star': '★5: Damage One Enemy [VI] &amp; HP Regeneration (All / 3 T) &amp; Remove All Status Ailments'}, 'Doppel': {'Name': 'Doppel: Andreana', 'Desc': 'The Doppel of mistaken steps<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>. Its form is cutting.\nThe master of this emotion fears her Doppel, as it unreservedly swings its blade to chop up everything in sight– even her precious books. Inwardly, though, she also feels a sense of release that she can’t quite describe.\nUnlike its ever-fearful master, the manifested Doppel chops with its guillotine without ever stopping to think. In addition to its target’s physical body, it shreds any and all magical connections they have.\nThis Doppel can only attack physically from very close range, and sometimes slashes at its allies by mistake, so it tends to leave itself open to attack. But the master of this emotion cannot control it, and so can only remain frozen in fear.', 'Ability': 'Damage One Enemy [VIII] &amp; Remove Buffs (Target) &amp; Regenerate HP (Allies / 3 T) &amp; Remove Status Ailments (Allies)'}}

# %%
girl_json = json.dumps(Kako)
print(girl_json)

with open('kako.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Kako Natsume", "Age": "Age: 13", "EyeColor": "Eye colour: Green", "HairColor": "Hair colour: Green", "Hometown": "Origins: Shinsei Ward", "SoulGem": "Soul Gem: Green open book (ribbon at her throat)", "Weapon": "Weapon: <a class=\"external text\" href=\"https://en.wikipedia.org/wiki/Spear\" rel=\"nofollow\">Spear> (Tip is squared)", "Wish": "Wish: \"I want to bring back my family's happiness! I want things like they were before... I want Natsume Library back!\"", "Ability": "Ability: Reproduction (Repeat what happened in front of you within the limits of your magic)", "Witch": "Witch form: Andreana", "Pronoun": "Japanese pronoun: <i>watashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u79c1</span>)</span", "School": "School: Kamihama City University Affiliated School Seventh Grade", "Disks": ["Accel", "Accel", "Blast", "Blast", "Charge"], "Stats": {"Initial": {"HP": "3267", "ATK": "977", "DEF": "11229"}, "Two_Star": {"HP": "10310", "ATK": "3190", "DEF": "3851"}, "Three_Star": {"HP": "13059", "ATK": "4044", "DEF": "4875"}, "Four_Star": {"HP": "17179", "ATK": "5325", "DEF": "6413"}, "Five_Star": {"HP": "21291", "ATK": "6609", "DEF": "7949"}, "SE": {"HP": "25771", "ATK": "7889", "DEF": "9726"}}, "Connect": {"Name": "Connect: On to the Next Page!", "Two_Star": "\u26052: HP Restore [III] &amp; Remove All Status Ailments", "Three_Star": "\u26053: HP Restore [V] &amp; Remove All Status Ailments", "Four_Star": "\u26054: HP Restore [VII] &amp; Remove All Status Ailments", "Five_Star": "\u26055: HP Restore [VIII] &amp; Remove All Status Ailments"}, "Magia": {"Name": "Magia: Page of Twinkle Road", "Two_Star": "\u26052: Damage One Enemy [I] &amp; HP Regeneration (All / 3 T)", "Three_Star": "\u26053: Damage One Enemy [II] &amp; HP Regeneration (All / 3 T)", "Four_Star": "\u26054: Damage One Enemy [IV] &amp; HP Regeneration (All / 3 T) &amp; Remove All Status Ailments", "Five_Star": "\u26055: Damage One Enemy [VI] &amp; HP Regeneration (All / 3 T) &amp; Remove All Status Ailments"}, "Doppel": {"Name": "Doppel: Andreana", "Desc": "The Doppel of mistaken steps<sup class=\"reference\" id=\"cite_ref-1\"><a href=\"#cite_note-1\">[1]</a></sup>. Its form is cutting.\nThe master of this emotion fears her Doppel, as it unreservedly swings its blade to chop up everything in sight\u2013 even her precious books. Inwardly, though, she also feels a sense of release that she can\u2019t quite describe.\nUnlike its ever-fearful master, the manifested Doppel chops with its guillotine without ever stopping to think. In addition to its target\u2019s physical body, it shreds any and all magical connections they have.\nThis Doppel can only attack physically from very close range, and sometimes slashes at its allies by mistake, so it tends to leave itself open to attack. But the master of this emotion cannot control it, and so can only remain frozen in fear.", "Ability": "Damage One Enemy [VIII] &amp; Remove Buffs (Target) &amp; Regenerate HP (Allies / 3 T) &amp; Remove Status Ailments (Allies)"}}

# %%
query_url = "https://wiki.puella-magi.net/Meiyui_Chun"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[15])
print(bullet_points[26])

para = soup.find_all('p')
para = str(para[4])
para = para.strip("<p>")
para = para.strip("</p>")
para = para.rstrip()
print(para)
# Out:
# <li><b>Age:</b> 17</li>
# <li><b>School:</b> <a href="/Schools#Chuo_Academy" title="Schools">Chuo Academy</a>, Eleventh Grade</li>
# The Doppel of Comfortable Sleep. Its form is a Towel.
# The Master of this emotion notes nonchalantly that this doppel is somewhat childish.
# A doppel quite opposite its master's sharpness in its infantile manners, it only wishes to nap.
# When this desire is impeded, it flails about in tantrum, and cries and wails in a voice that destroys the eardrums of those who oppose it. When this doppel yawns, all around it, whether friend or foe, are hit by an sudden and irresistible urge to sleep. Those who rest against its soft body are guaranteed to doze blissfully in a nap like no other.

# %%
table_data = soup.find_all('td')

initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

# max at 3* 32, 33, 34, 35
three_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 36, 37, 38, 39
four_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 5* [40], [41], [42], [43]
five_star_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# Max SE 44, 45, 46, 47
se_hp = str(table_data[37]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_atk = str(table_data[38]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_def = str(table_data[39]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(three_star_hp, three_star_atk, three_star_def)
print(four_star_hp, four_star_atk, four_star_def)
print(five_star_hp, five_star_atk, five_star_def)
print(se_hp, se_atk, se_def)

disk_one = str(table_data[40])
disk_two = str(table_data[41])
disk_three = str(table_data[42])
disk_four = str(table_data[43])
disk_five = str(table_data[44])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)

# table_data 49 through 52 are Connect Info
connect_three_star = str(table_data[45])
connect_four_star = str(table_data[46])
connect_five_star = str(table_data[47])

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

connect_five_star = connect_five_star.replace('</td>', '')
connect_five_star = connect_five_star.replace('<td style="width:100%;">', '')
connect_five_star = connect_five_star.rstrip()
print(connect_five_star)

# table_data 53 through 56 are Magia Info

magia_three_star = str(table_data[48])
magia_four_star = str(table_data[49])
magia_five_star = str(table_data[50])

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

magia_five_star = magia_five_star.replace('</td>', '')
magia_five_star = magia_five_star.replace('<td style="width:100%;">', '')
magia_five_star = magia_five_star.rstrip()
print(magia_five_star)

doppel_info = str(table_data[51])
doppel_info = doppel_info.replace('<td style="width:100%;">', '')
doppel_info = doppel_info.replace('</td>', '')
doppel_info = doppel_info.rstrip()
print(doppel_info)

table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
doppel = str(table_head[5])
print(magia)
print(doppel)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)

doppel = doppel.strip('<th colspan="5">')
doppel = doppel.strip('b>')
doppel = doppel.replace('<b>', '')
doppel = doppel.replace('</b>', '')
doppel = doppel.replace('<i>', '')
doppel = doppel.replace('</i>', '')
doppel = doppel.strip('</')
doppel = doppel.rstrip()
print(doppel)
# Out:
# 5013 1256 1660
# 16683 4210 5843
# 21677 5471 7605
# 26662 6733 9379
# 30373 8421 12935
# ['Accel', 'Blast', 'Charge', 'Charge', 'Charge']
# ★3: Guaranteed Evade &amp; Probability Critical [V]
# ★4: Guaranteed Evade &amp; Probability Critical [VII]
# ★5: Guaranteed Evade &amp; Probability Critical [IX]
# ★3: Damage One Enemy [III] &amp; Guaranteed Evasion (Self / 1 T)
# ★4: Damage Three Random Enemies [V] &amp; Guaranteed Evasion (Self / 1 T)
# ★5: Damage Four Enemies [VII] &amp; Guaranteed Evasion (Self / 1 T) &amp; Charged Damage UP (Allies / 3 T)
# Damage Five Random Enemies [IX] &amp; Guaranteed Evasion (Self / 2 T) &amp; Charged Damage UP (Allies / 3 T)
# <th colspan="5"><b>Magia:</b> <i>Hawk Shadow Slash</i>
# </th>
# <th colspan="5">Doppel:<b> <i>Delanna</i></b>
# </th>
# Connect: Cooperation Is Our Motto
# Magia: Hawk Shadow Slash
# Doppel: Delanna

# %%
Age = str(bullet_points[15]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[16]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[25]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Witch)
Pronoun = str(bullet_points[26]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[27]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)

Meiyui = {
    "Name": "Meiyui Chun",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "Five_Star": {
            "HP": five_star_hp,
            "ATK": five_star_atk,
            "DEF": five_star_def        
        },
        "SE": {
            "HP": se_hp,
            "ATK": se_atk,
            "DEF":  se_def          
        }
    },
    "Connect": {
        "Name": connect,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star,
        "Five_Star": connect_five_star
    },
    "Magia": {
        "Name": magia,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star,
        "Five_Star": magia_five_star
    },
    "Doppel": {
        "Name": doppel,
        "Desc": para,
        "Ability": doppel_info,
    }
}

print(Meiyui)
# Out:
# Age: 17
# Height: 163cm
# Eye colour: Blue
# Hair colour: Blue
# Origins: Minagi Ward
# Soul Gem: Blue oval (beneath neck)
# Wish: "I want to protect the Blue Seas Family."
# Ability: Falsification of the truth (change target's perception)
# Witch form: Delanna
# Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span
# School: <a href="/Schools#Chuo_Academy" title="Schools">Chuo Academy</a> Eleventh Grade
# a class="mw-redirect" href="/And_So_The_Azalea_Blooms" title="And So The Azalea Blooms">And So The Azalea Blooms</a>.
# {'Name': 'Meiyui Chun', 'Age': 'Age: 17', 'EyeColor': 'Eye colour: Blue', 'HairColor': 'Hair colour: Blue', 'Hometown': 'Origins: Minagi Ward', 'SoulGem': 'Soul Gem: Blue oval (beneath neck)', 'Weapon': 'Wish: "I want to protect the Blue Seas Family."', 'Wish': "Ability: Falsification of the truth (change target's perception)", 'Ability': 'Witch form: Delanna', 'Witch': 'Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'Pronoun': 'School: <a href="/Schools#Chuo_Academy" title="Schools">Chuo Academy</a> Eleventh Grade', 'School': 'a class="mw-redirect" href="/And_So_The_Azalea_Blooms" title="And So The Azalea Blooms">And So The Azalea Blooms</a>.', 'Disks': ['Accel', 'Blast', 'Charge', 'Charge', 'Charge'], 'Stats': {'Initial': {'HP': '5013', 'ATK': '1256', 'DEF': '1660'}, 'Three_Star': {'HP': '16683', 'ATK': '4210', 'DEF': '5843'}, 'Four_Star': {'HP': '21677', 'ATK': '5471', 'DEF': '7605'}, 'Five_Star': {'HP': '26662', 'ATK': '6733', 'DEF': '9379'}, 'SE': {'HP': '30373', 'ATK': '8421', 'DEF': '12935'}}, 'Connect': {'Name': 'Connect: Cooperation Is Our Motto', 'Three_Star': '★3: Guaranteed Evade &amp; Probability Critical [V]', 'Four_Star': '★4: Guaranteed Evade &amp; Probability Critical [VII]', 'Five_Star': '★5: Guaranteed Evade &amp; Probability Critical [IX]'}, 'Magia': {'Name': 'Magia: Hawk Shadow Slash', 'Three_Star': '★3: Damage One Enemy [III] &amp; Guaranteed Evasion (Self / 1 T)', 'Four_Star': '★4: Damage Three Random Enemies [V] &amp; Guaranteed Evasion (Self / 1 T)', 'Five_Star': '★5: Damage Four Enemies [VII] &amp; Guaranteed Evasion (Self / 1 T) &amp; Charged Damage UP (Allies / 3 T)'}, 'Doppel': {'Name': 'Doppel: Delanna', 'Desc': "The Doppel of Comfortable Sleep. Its form is a Towel.\nThe Master of this emotion notes nonchalantly that this doppel is somewhat childish.\nA doppel quite opposite its master's sharpness in its infantile manners, it only wishes to nap.\nWhen this desire is impeded, it flails about in tantrum, and cries and wails in a voice that destroys the eardrums of those who oppose it. When this doppel yawns, all around it, whether friend or foe, are hit by an sudden and irresistible urge to sleep. Those who rest against its soft body are guaranteed to doze blissfully in a nap like no other.", 'Ability': 'Damage Five Random Enemies [IX] &amp; Guaranteed Evasion (Self / 2 T) &amp; Charged Damage UP (Allies / 3 T)'}}

# %%
girl_json = json.dumps(Meiyui)
print(girl_json)

with open('meiyui.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Meiyui Chun", "Age": "Age: 17", "EyeColor": "Eye colour: Blue", "HairColor": "Hair colour: Blue", "Hometown": "Origins: Minagi Ward", "SoulGem": "Soul Gem: Blue oval (beneath neck)", "Weapon": "Wish: \"I want to protect the Blue Seas Family.\"", "Wish": "Ability: Falsification of the truth (change target's perception)", "Ability": "Witch form: Delanna", "Witch": "Japanese pronoun: <i>watashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u79c1</span>)</span", "Pronoun": "School: <a href=\"/Schools#Chuo_Academy\" title=\"Schools\">Chuo Academy</a> Eleventh Grade", "School": "a class=\"mw-redirect\" href=\"/And_So_The_Azalea_Blooms\" title=\"And So The Azalea Blooms\">And So The Azalea Blooms</a>.", "Disks": ["Accel", "Blast", "Charge", "Charge", "Charge"], "Stats": {"Initial": {"HP": "5013", "ATK": "1256", "DEF": "1660"}, "Three_Star": {"HP": "16683", "ATK": "4210", "DEF": "5843"}, "Four_Star": {"HP": "21677", "ATK": "5471", "DEF": "7605"}, "Five_Star": {"HP": "26662", "ATK": "6733", "DEF": "9379"}, "SE": {"HP": "30373", "ATK": "8421", "DEF": "12935"}}, "Connect": {"Name": "Connect: Cooperation Is Our Motto", "Three_Star": "\u26053: Guaranteed Evade &amp; Probability Critical [V]", "Four_Star": "\u26054: Guaranteed Evade &amp; Probability Critical [VII]", "Five_Star": "\u26055: Guaranteed Evade &amp; Probability Critical [IX]"}, "Magia": {"Name": "Magia: Hawk Shadow Slash", "Three_Star": "\u26053: Damage One Enemy [III] &amp; Guaranteed Evasion (Self / 1 T)", "Four_Star": "\u26054: Damage Three Random Enemies [V] &amp; Guaranteed Evasion (Self / 1 T)", "Five_Star": "\u26055: Damage Four Enemies [VII] &amp; Guaranteed Evasion (Self / 1 T) &amp; Charged Damage UP (Allies / 3 T)"}, "Doppel": {"Name": "Doppel: Delanna", "Desc": "The Doppel of Comfortable Sleep. Its form is a Towel.\nThe Master of this emotion notes nonchalantly that this doppel is somewhat childish.\nA doppel quite opposite its master's sharpness in its infantile manners, it only wishes to nap.\nWhen this desire is impeded, it flails about in tantrum, and cries and wails in a voice that destroys the eardrums of those who oppose it. When this doppel yawns, all around it, whether friend or foe, are hit by an sudden and irresistible urge to sleep. Those who rest against its soft body are guaranteed to doze blissfully in a nap like no other.", "Ability": "Damage Five Random Enemies [IX] &amp; Guaranteed Evasion (Self / 2 T) &amp; Charged Damage UP (Allies / 3 T)"}}
