# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import json
import requests

query_url = "https://wiki.puella-magi.net/Asuka_Tatsuki"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[17])
print(bullet_points[28])

para = soup.find_all('p')
para = str(para[3])
para = para.strip("<p>")
para = para.strip("</p>")
para = para.rstrip()
print(para)
# Out:
# <li><b>Age:</b> 16</li>
# <li><b>School:</b> Mizuna Girls' School, Tenth Grade</li>
# The Doppel of assault. Its form is a war drum. The master of this emotion is eager to become stronger through her Doppel's power. It energizes itself with the beat of its drum and sends out orders to turn its allies into valiant warriors. However, it also shares its master's hastiness, so once the order is given, its allies are forced to perform an act of utter disgrace against their will. Its reputation with its allies is terrible as a result of this unreasonableness. It is difficult to handle as, like its master, it attempts to kill itself after committing a blunder.

# %%
table_data = soup.find_all('td')

initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

# max at 3* 32, 33, 34, 35
three_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 36, 37, 38, 39
four_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 5* [40], [41], [42], [43]
five_star_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# Max SE 44, 45, 46, 47
se_hp = str(table_data[37]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_atk = str(table_data[38]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_def = str(table_data[39]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(three_star_hp, three_star_atk, three_star_def)
print(four_star_hp, four_star_atk, four_star_def)
print(five_star_hp, five_star_atk, five_star_def)
print(se_hp, se_atk, se_def)

disk_one = str(table_data[40])
disk_two = str(table_data[41])
disk_three = str(table_data[42])
disk_four = str(table_data[43])
disk_five = str(table_data[44])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)

# table_data 49 through 52 are Connect Info
connect_three_star = str(table_data[45])
connect_four_star = str(table_data[46])
connect_five_star = str(table_data[47])

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

connect_five_star = connect_five_star.replace('</td>', '')
connect_five_star = connect_five_star.replace('<td style="width:100%;">', '')
connect_five_star = connect_five_star.rstrip()
print(connect_five_star)

# table_data 53 through 56 are Magia Info

magia_three_star = str(table_data[48])
magia_four_star = str(table_data[49])
magia_five_star = str(table_data[50])

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

magia_five_star = magia_five_star.replace('</td>', '')
magia_five_star = magia_five_star.replace('<td style="width:100%;">', '')
magia_five_star = magia_five_star.rstrip()
print(magia_five_star)

doppel_info = str(table_data[51])
doppel_info = doppel_info.replace('<td style="width:100%;">', '')
doppel_info = doppel_info.replace('</td>', '')
doppel_info = doppel_info.rstrip()
print(doppel_info)

table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
doppel = str(table_head[5])
print(magia)
print(doppel)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)

doppel = doppel.strip('<th colspan="5">')
doppel = doppel.strip('b>')
doppel = doppel.replace('<b>', '')
doppel = doppel.replace('</b>', '')
doppel = doppel.replace('<i>', '')
doppel = doppel.replace('</i>', '')
doppel = doppel.strip('</')
doppel = doppel.rstrip()
print(doppel)
# Out:
# 4557 1462 1520
# 15165 4900 5350
# 19709 6368 6963
# 24801 7836 8727
# 27833 8906 12160
# ['Accel', 'Blast', 'Blast', 'Blast', 'Charge']
# ★3: Guaranteed Provoke &amp; Damage Cut [V]
# ★4: Guaranteed Provoke &amp; Damage Cut [VII]
# ★5: Guaranteed Provoke &amp; Damage Cut [IX]
# ★3: Damage One Enemy [III] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 1 T)
# ★4: Damage One Enemy [V] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 3 T)
# ★5: Damage One Enemy [V] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 3 T) &amp; Damage Cut (Self / 3 T)
# Damage One Enemy [IX] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 3 T) &amp; Damage Cut (All / 3 T)
# <th colspan="5"><b>Magia:</b> <i>Shining Dragon Fang</i>
# </th>
# <th colspan="5"><b>Doppel:</b> <i>Henrietta</i>
# </th>
# Connect: I'll Serve as Support!
# Magia: Shining Dragon Fang
# Doppel: Henrietta

# %%
Age = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[25]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[26]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Witch)
Pronoun = str(bullet_points[27]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[28]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)

Asuka = {
    "Name": "Asuka Tatsuki",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "Five_Star": {
            "HP": five_star_hp,
            "ATK": five_star_atk,
            "DEF": five_star_def        
        },
        "SE": {
            "HP": se_hp,
            "ATK": se_atk,
            "DEF":  se_def          
        }
    },
    "Connect": {
        "Name": connect,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star,
        "Five_Star": connect_five_star
    },
    "Magia": {
        "Name": magia,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star,
        "Five_Star": magia_five_star
    },
    "Doppel": {
        "Name": doppel,
        "Desc": para,
        "Ability": doppel_info,
    }
}

print(Asuka)
# Out:
# Age: 16
# Height: 160cm
# Eye colour: Purple
# Hair colour: Dark Blue
# Origins: Mizuna Ward
# Soul Gem: Blue <a class="external text" href="https://en.m.wikipedia.org/wiki/Magatama" rel="nofollow">Magatama</a> (Obi)
# Weapon: <a class="external text" href="https://en.m.wikipedia.org/wiki/Naginata" rel="nofollow">Naginata
# Wish: "Please let my cousin become a police officer".
# Ability: Discipline (Temporary Obedience)
# Witch form: Henrietta
# Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span
# School: Mizuna Girls' School Tenth Grade
# {'Name': 'Asuka Tatsuki', 'Age': 'Age: 16', 'EyeColor': 'Eye colour: Purple', 'HairColor': 'Hair colour: Dark Blue', 'Hometown': 'Origins: Mizuna Ward', 'SoulGem': 'Soul Gem: Blue <a class="external text" href="https://en.m.wikipedia.org/wiki/Magatama" rel="nofollow">Magatama</a> (Obi)', 'Weapon': 'Weapon: <a class="external text" href="https://en.m.wikipedia.org/wiki/Naginata" rel="nofollow">Naginata', 'Wish': 'Wish: "Please let my cousin become a police officer".', 'Ability': 'Ability: Discipline (Temporary Obedience)', 'Witch': 'Witch form: Henrietta', 'Pronoun': 'Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'School': "School: Mizuna Girls' School Tenth Grade", 'Disks': ['Accel', 'Blast', 'Blast', 'Blast', 'Charge'], 'Stats': {'Initial': {'HP': '4557', 'ATK': '1462', 'DEF': '1520'}, 'Three_Star': {'HP': '15165', 'ATK': '4900', 'DEF': '5350'}, 'Four_Star': {'HP': '19709', 'ATK': '6368', 'DEF': '6963'}, 'Five_Star': {'HP': '24801', 'ATK': '7836', 'DEF': '8727'}, 'SE': {'HP': '27833', 'ATK': '8906', 'DEF': '12160'}}, 'Connect': {'Name': "Connect: I'll Serve as Support!", 'Three_Star': '★3: Guaranteed Provoke &amp; Damage Cut [V]', 'Four_Star': '★4: Guaranteed Provoke &amp; Damage Cut [VII]', 'Five_Star': '★5: Guaranteed Provoke &amp; Damage Cut [IX]'}, 'Magia': {'Name': 'Magia: Shining Dragon Fang', 'Three_Star': '★3: Damage One Enemy [III] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 1 T)', 'Four_Star': '★4: Damage One Enemy [V] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 3 T)', 'Five_Star': '★5: Damage One Enemy [V] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 3 T) &amp; Damage Cut (Self / 3 T)'}, 'Doppel': {'Name': 'Doppel: Henrietta', 'Desc': "The Doppel of assault. Its form is a war drum. The master of this emotion is eager to become stronger through her Doppel's power. It energizes itself with the beat of its drum and sends out orders to turn its allies into valiant warriors. However, it also shares its master's hastiness, so once the order is given, its allies are forced to perform an act of utter disgrace against their will. Its reputation with its allies is terrible as a result of this unreasonableness. It is difficult to handle as, like its master, it attempts to kill itself after committing a blunder.", 'Ability': 'Damage One Enemy [IX] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 3 T) &amp; Damage Cut (All / 3 T)'}}

# %%
girl_json = json.dumps(Asuka)
print(girl_json)

with open('asuka.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Asuka Tatsuki", "Age": "Age: 16", "EyeColor": "Eye colour: Purple", "HairColor": "Hair colour: Dark Blue", "Hometown": "Origins: Mizuna Ward", "SoulGem": "Soul Gem: Blue <a class=\"external text\" href=\"https://en.m.wikipedia.org/wiki/Magatama\" rel=\"nofollow\">Magatama</a> (Obi)", "Weapon": "Weapon: <a class=\"external text\" href=\"https://en.m.wikipedia.org/wiki/Naginata\" rel=\"nofollow\">Naginata", "Wish": "Wish: \"Please let my cousin become a police officer\".", "Ability": "Ability: Discipline (Temporary Obedience)", "Witch": "Witch form: Henrietta", "Pronoun": "Japanese pronoun: <i>watashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u79c1</span>)</span", "School": "School: Mizuna Girls' School Tenth Grade", "Disks": ["Accel", "Blast", "Blast", "Blast", "Charge"], "Stats": {"Initial": {"HP": "4557", "ATK": "1462", "DEF": "1520"}, "Three_Star": {"HP": "15165", "ATK": "4900", "DEF": "5350"}, "Four_Star": {"HP": "19709", "ATK": "6368", "DEF": "6963"}, "Five_Star": {"HP": "24801", "ATK": "7836", "DEF": "8727"}, "SE": {"HP": "27833", "ATK": "8906", "DEF": "12160"}}, "Connect": {"Name": "Connect: I'll Serve as Support!", "Three_Star": "\u26053: Guaranteed Provoke &amp; Damage Cut [V]", "Four_Star": "\u26054: Guaranteed Provoke &amp; Damage Cut [VII]", "Five_Star": "\u26055: Guaranteed Provoke &amp; Damage Cut [IX]"}, "Magia": {"Name": "Magia: Shining Dragon Fang", "Three_Star": "\u26053: Damage One Enemy [III] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 1 T)", "Four_Star": "\u26054: Damage One Enemy [V] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 3 T)", "Five_Star": "\u26055: Damage One Enemy [V] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 3 T) &amp; Damage Cut (Self / 3 T)"}, "Doppel": {"Name": "Doppel: Henrietta", "Desc": "The Doppel of assault. Its form is a war drum. The master of this emotion is eager to become stronger through her Doppel's power. It energizes itself with the beat of its drum and sends out orders to turn its allies into valiant warriors. However, it also shares its master's hastiness, so once the order is given, its allies are forced to perform an act of utter disgrace against their will. Its reputation with its allies is terrible as a result of this unreasonableness. It is difficult to handle as, like its master, it attempts to kill itself after committing a blunder.", "Ability": "Damage One Enemy [IX] &amp; Provoke (Self / 1 T) &amp; HP Restore (Self / 3 T) &amp; Damage Cut (All / 3 T)"}}

# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import json
import requests

query_url = "https://wiki.puella-magi.net/Kanoko_Yayoi"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[14])
print(bullet_points[25])
# Out:
# <li><b>Age:</b> 16</li>
# <li><b>School:</b> Mizuna Girls' School, Tenth Grade</li>

# %%
table_data = soup.find_all('td')

initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 2* 28, 29, 30, 31
two_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 3* 32, 33, 34, 35
three_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 36, 37, 38, 39
four_star_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# Max SE 44, 45, 46, 47
se_hp = str(table_data[37]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_atk = str(table_data[38]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_def = str(table_data[39]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(two_star_hp, two_star_atk, two_star_def)
print(three_star_hp, three_star_atk, three_star_def)
print(four_star_hp, four_star_atk, four_star_def)
print(se_hp, se_atk, se_def)
# Out:
# 3085 1287 1072
# 9668 4061 3405
# 12247 5145 4322
# 16106 6769 5691
# 19195 7985 7902

# %%
disk_one = str(table_data[40])
disk_two = str(table_data[41])
disk_three = str(table_data[42])
disk_four = str(table_data[43])
disk_five = str(table_data[44])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)
# Out:
# ['Accel', 'Accel', 'Blast', 'Charge', 'Charge']

# %%
# table_data 49 through 52 are Connect Info
connect_two_star = str(table_data[45])
connect_three_star = str(table_data[46])
connect_four_star = str(table_data[47])

connect_two_star = connect_two_star.replace('</td>', '')
connect_two_star = connect_two_star.replace('<td style="width:100%;">', '')
connect_two_star = connect_two_star.rstrip()
print(connect_two_star)

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

# table_data 53 through 56 are Magia Info

magia_two_star = str(table_data[48])
magia_three_star = str(table_data[49])
magia_four_star = str(table_data[50])

magia_two_star = magia_two_star.replace('</td>', '')
magia_two_star = magia_two_star.replace('<td style="width:100%;">', '')
magia_two_star = magia_two_star.rstrip()
print(magia_two_star)

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)
# Out:
# ★2: Damage UP [III] &amp; Guaranteed Charm Edge
# ★3: Damage UP [V] &amp; Guaranteed Charm Edge
# ★4: Damage UP [VII] &amp; Guaranteed Charm Edge
# ★2: Damage One Enemy [I] &amp; Guaranteed Charm (Enemy / 1 T)
# ★3: Damage Two Random Enemies [III] &amp; Guaranteed Charm (Enemy / 1 T)
# ★4: Damage Three Random Enemies [V] &amp; Guaranteed Charm (Enemy / 1 T)

# %%
table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
print(magia)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)
# Out:
# <th colspan="5"><b>Magia:</b> <i>Yayoi Collection</i>
# </th>
# Connect: Our Collaborative Design!
# Magia: Yayoi Collection

# %%
Age = str(bullet_points[14]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[15]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[16]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '').replace('</', '')
print(Witch)
Pronoun = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[25]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)
# Out:
# Age: 16
# Height: 160cm
# Eye colour: Dark green
# Hair colour: Brown
# Origins: Kosho Ward
# Soul Gem: Dark green gem in the shape of a needle threader (choker)
# Weapon: <a class="extiw" href="https://en.wikipedia.org/wiki/Sword" title="wikipedia:Sword">Sword> (resembling a giant sewing needle)
# Wish: "I want my parents to be able to work for 30 more years."
# Ability: Sewing (To sew anything with thread)
# Witch form:
# Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span
# School: Mizuna Girls' School Tenth Grade

# %%
Kanoko = {
    "Name": "Kanoko Yayoi",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Two_Star": {
            "HP": two_star_hp,
            "ATK": two_star_atk,
            "DEF": two_star_def 
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "SE": {
            "HP": se_hp,
            "ATK": se_atk,
            "DEF":  se_def          
        }
    },
    "Connect": {
        "Name": connect,
        "Two_Star": connect_two_star,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star
    },
    "Magia": {
        "Name": magia,
        "Two_Star": magia_two_star,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star
    },
    "Doppel": {
        "Name": ""
    }
}

print(Kanoko)
# Out:
# {'Name': 'Kanoko Yayoi', 'Age': 'Age: 14', 'EyeColor': 'Eye colour: Blue', 'HairColor': 'Hair colour: Light Blue', 'Hometown': 'Origins: Sankyo Ward', 'SoulGem': 'Soul Gem: Blue heart (belt)', 'Weapon': 'Weapon: Cheerleader Baton', 'Wish': 'Wish: "I want to cure my big brother\'s illness." (So he could play a championship baseball game)', 'Ability': 'Ability: Cheering', 'Witch': 'Witch form:', 'Pronoun': 'Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'School': 'School: Sankyoin Educational Academy Eighth Grade', 'Disks': ['Accel', 'Blast', 'Blast', 'Charge', 'Charge'], 'Stats': {'Initial': {'HP': '3866', 'ATK': '1059', 'DEF': '1065'}, 'Two_Star': {'HP': '12456', 'ATK': '3365', 'DEF': '3454'}, 'Three_Star': {'HP': '15788', 'ATK': '4263', 'DEF': '4378'}, 'Four_Star': {'HP': '20776', 'ATK': '5611', 'DEF': '5762'}, 'SE': {'HP': '19195', 'ATK': '7985', 'DEF': '7902'}}, 'Connect': {'Name': 'Connect: We Can Do It!', 'Two_Star': '★2: Attack UP [IV] &amp; Defense UP [IV]', 'Three_Star': '★3: Attack UP [VI] &amp; Defense UP [VI]', 'Four_Star': '★4: Attack UP [VIII] &amp; Defense UP [VIII]'}, 'Magia': {'Name': 'Magia: Go! Fight! Win!', 'Two_Star': '★2: Damage One Enemy [I] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T)', 'Three_Star': '★3: Damage One Enemy [III] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T)', 'Four_Star': '★4: Damage One Enemy [V] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T) &amp; Damage Cut (All / 3 T)'}, 'Doppel': {'Name': ''}}

# %%
girl_json = json.dumps(Kanoko)
print(girl_json)

with open('kanoko.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Kanoko Yayoi", "Age": "Age: 14", "EyeColor": "Eye colour: Blue", "HairColor": "Hair colour: Light Blue", "Hometown": "Origins: Sankyo Ward", "SoulGem": "Soul Gem: Blue heart (belt)", "Weapon": "Weapon: Cheerleader Baton", "Wish": "Wish: \"I want to cure my big brother's illness.\" (So he could play a championship baseball game)", "Ability": "Ability: Cheering", "Witch": "Witch form:", "Pronoun": "Japanese pronoun: <i>watashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u79c1</span>)</span", "School": "School: Sankyoin Educational Academy Eighth Grade", "Disks": ["Accel", "Blast", "Blast", "Charge", "Charge"], "Stats": {"Initial": {"HP": "3866", "ATK": "1059", "DEF": "1065"}, "Two_Star": {"HP": "12456", "ATK": "3365", "DEF": "3454"}, "Three_Star": {"HP": "15788", "ATK": "4263", "DEF": "4378"}, "Four_Star": {"HP": "20776", "ATK": "5611", "DEF": "5762"}, "SE": {"HP": "19195", "ATK": "7985", "DEF": "7902"}}, "Connect": {"Name": "Connect: We Can Do It!", "Two_Star": "\u26052: Attack UP [IV] &amp; Defense UP [IV]", "Three_Star": "\u26053: Attack UP [VI] &amp; Defense UP [VI]", "Four_Star": "\u26054: Attack UP [VIII] &amp; Defense UP [VIII]"}, "Magia": {"Name": "Magia: Go! Fight! Win!", "Two_Star": "\u26052: Damage One Enemy [I] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T)", "Three_Star": "\u26053: Damage One Enemy [III] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T)", "Four_Star": "\u26054: Damage One Enemy [V] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T) &amp; Damage Cut (All / 3 T)"}, "Doppel": {"Name": ""}}

# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import json
import requests

query_url = "https://wiki.puella-magi.net/Natsuki_Utsuho"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[15])
print(bullet_points[26])
# Out:
# <li><b>Age:</b> 14</li>
# <li><b>School:</b> Sankyoin Educational Academy, Eighth Grade</li>

# %%
table_data = soup.find_all('td')

initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 2* 28, 29, 30, 31
two_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 3* 32, 33, 34, 35
three_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 36, 37, 38, 39
four_star_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(two_star_hp, two_star_atk, two_star_def)
print(three_star_hp, three_star_atk, three_star_def)
print(four_star_hp, four_star_atk, four_star_def)
# Out:
# 3866 1059 1065
# 12456 3365 3454
# 15788 4263 4378
# 20776 5611 5762

# %%
disk_one = str(table_data[36])
disk_two = str(table_data[37])
disk_three = str(table_data[38])
disk_four = str(table_data[39])
disk_five = str(table_data[40])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)
# Out:
# ['Accel', 'Blast', 'Blast', 'Charge', 'Charge']

# %%
# table_data 49 through 52 are Connect Info
connect_two_star = str(table_data[41])
connect_three_star = str(table_data[42])
connect_four_star = str(table_data[43])

connect_two_star = connect_two_star.replace('</td>', '')
connect_two_star = connect_two_star.replace('<td style="width:100%;">', '')
connect_two_star = connect_two_star.rstrip()
print(connect_two_star)

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

# table_data 53 through 56 are Magia Info

magia_two_star = str(table_data[44])
magia_three_star = str(table_data[45])
magia_four_star = str(table_data[46])

magia_two_star = magia_two_star.replace('</td>', '')
magia_two_star = magia_two_star.replace('<td style="width:100%;">', '')
magia_two_star = magia_two_star.rstrip()
print(magia_two_star)

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)
# Out:
# ★2: Attack UP [IV] &amp; Defense UP [IV]
# ★3: Attack UP [VI] &amp; Defense UP [VI]
# ★4: Attack UP [VIII] &amp; Defense UP [VIII]
# ★2: Damage One Enemy [I] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T)
# ★3: Damage One Enemy [III] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T)
# ★4: Damage One Enemy [V] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T) &amp; Damage Cut (All / 3 T)

# %%
table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
print(magia)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)
# Out:
# <th colspan="5"><b>Magia:</b> <i>Go! Fight! Win!</i>
# </th>
# Connect: We Can Do It!
# Magia: Go! Fight! Win!

# %%
Age = str(bullet_points[15]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[16]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '').replace('</', '')
print(Witch)
Pronoun = str(bullet_points[25]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[26]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)
# Out:
# Age: 14
# Height: 157cm
# Eye colour: Blue
# Hair colour: Light Blue
# Origins: Sankyo Ward
# Soul Gem: Blue heart (belt)
# Weapon: Cheerleader Baton
# Wish: "I want to cure my big brother's illness." (So he could play a championship baseball game)
# Ability: Cheering
# Witch form:
# Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span
# School: Sankyoin Educational Academy Eighth Grade

# %%
Natsuki = {
    "Name": "Natsuki Utsuho",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Two_Star": {
            "HP": two_star_hp,
            "ATK": two_star_atk,
            "DEF": two_star_def 
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        }
    },
    "Connect": {
        "Name": connect,
        "Two_Star": connect_two_star,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star
    },
    "Magia": {
        "Name": magia,
        "Two_Star": magia_two_star,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star
    },
    "Doppel": {
        "Name": ""
    }
}

print(Natsuki)
# Out:
# {'Name': 'Natsuki Utsuho', 'Age': 'Age: 14', 'EyeColor': 'Eye colour: Blue', 'HairColor': 'Hair colour: Light Blue', 'Hometown': 'Origins: Sankyo Ward', 'SoulGem': 'Soul Gem: Blue heart (belt)', 'Weapon': 'Weapon: Cheerleader Baton', 'Wish': 'Wish: "I want to cure my big brother\'s illness." (So he could play a championship baseball game)', 'Ability': 'Ability: Cheering', 'Witch': 'Witch form:', 'Pronoun': 'Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'School': 'School: Sankyoin Educational Academy Eighth Grade', 'Disks': ['Accel', 'Blast', 'Blast', 'Charge', 'Charge'], 'Stats': {'Initial': {'HP': '3866', 'ATK': '1059', 'DEF': '1065'}, 'Two_Star': {'HP': '12456', 'ATK': '3365', 'DEF': '3454'}, 'Three_Star': {'HP': '15788', 'ATK': '4263', 'DEF': '4378'}, 'Four_Star': {'HP': '20776', 'ATK': '5611', 'DEF': '5762'}}, 'Connect': {'Name': 'Connect: We Can Do It!', 'Two_Star': '★2: Attack UP [IV] &amp; Defense UP [IV]', 'Three_Star': '★3: Attack UP [VI] &amp; Defense UP [VI]', 'Four_Star': '★4: Attack UP [VIII] &amp; Defense UP [VIII]'}, 'Magia': {'Name': 'Magia: Go! Fight! Win!', 'Two_Star': '★2: Damage One Enemy [I] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T)', 'Three_Star': '★3: Damage One Enemy [III] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T)', 'Four_Star': '★4: Damage One Enemy [V] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T) &amp; Damage Cut (All / 3 T)'}, 'Doppel': {'Name': ''}}

# %%
girl_json = json.dumps(Natsuki)
print(girl_json)

with open('natsuki.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Natsuki Utsuho", "Age": "Age: 14", "EyeColor": "Eye colour: Blue", "HairColor": "Hair colour: Light Blue", "Hometown": "Origins: Sankyo Ward", "SoulGem": "Soul Gem: Blue heart (belt)", "Weapon": "Weapon: Cheerleader Baton", "Wish": "Wish: \"I want to cure my big brother's illness.\" (So he could play a championship baseball game)", "Ability": "Ability: Cheering", "Witch": "Witch form:", "Pronoun": "Japanese pronoun: <i>watashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u79c1</span>)</span", "School": "School: Sankyoin Educational Academy Eighth Grade", "Disks": ["Accel", "Blast", "Blast", "Charge", "Charge"], "Stats": {"Initial": {"HP": "3866", "ATK": "1059", "DEF": "1065"}, "Two_Star": {"HP": "12456", "ATK": "3365", "DEF": "3454"}, "Three_Star": {"HP": "15788", "ATK": "4263", "DEF": "4378"}, "Four_Star": {"HP": "20776", "ATK": "5611", "DEF": "5762"}}, "Connect": {"Name": "Connect: We Can Do It!", "Two_Star": "\u26052: Attack UP [IV] &amp; Defense UP [IV]", "Three_Star": "\u26053: Attack UP [VI] &amp; Defense UP [VI]", "Four_Star": "\u26054: Attack UP [VIII] &amp; Defense UP [VIII]"}, "Magia": {"Name": "Magia: Go! Fight! Win!", "Two_Star": "\u26052: Damage One Enemy [I] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T)", "Three_Star": "\u26053: Damage One Enemy [III] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T)", "Four_Star": "\u26054: Damage One Enemy [V] &amp; Attack UP (All / 3 T) &amp; Defense UP (All / 3 T) &amp; Damage Cut (All / 3 T)"}, "Doppel": {"Name": ""}}
