# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import json
import requests

query_url = "https://wiki.puella-magi.net/Hinano_Miyako"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[18])
print(bullet_points[29])

para = soup.find_all('p')
para = str(para[3])
para = para.strip("<p>")
para = para.strip("</p>")
para = para.rstrip()
print(para)
# Out:
# <li><b>Age:</b> 18</li>
# <li><b>School:</b> Minagi Freedom School, Twelfth Grade</li>
# The Doppel of imprudence. Its form is smog.
# The master of this Doppel is thrilled with its legs, which have grown much longer. It boils the contents of its right leg and condenses the contents of its left to cause the chemical reaction that forms its gaseous upper body. It therefore boasts a high resistance to physical attacks; however, it also envelops enemy and ally alike in its toxicity. Once it appears, its surroundings are contaminated by its gas, and even its master would likely not be able to withstand it if she did not wear a gas mask. It also has a strong curiosity for rare kinds of Witches.

# %%
table_data = soup.find_all('td')

# table_data[8] through
# Headers no1 8, 9,10, 11
# Data 12, 13, 14, 15 - 15 is a Link Picture
# Headers no2 16, 17, 18, 19
# initial 20, 21, 22, 23
initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 2* 25, 26, 27
two_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 3* 29, 30, 31
three_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 33, 34, 35
four_star_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 5* 37, 38, 39
five_star_hp = str(table_data[37]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_atk = str(table_data[38]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_def = str(table_data[39]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(two_star_hp, two_star_atk, two_star_def)
print(three_star_hp, three_star_atk, three_star_def)
print(four_star_hp, four_star_atk, four_star_def)
print(five_star_hp, five_star_atk, five_star_def)
# Out:
# 4101 1182 1587
# 12114 3490 3431
# 20189 5828 5721
# 20189 5828 5721
# 25030 7230 7100

# %%
# data 44 through 48 is disks
# if condition on alt attribute to determine what type of data to put where

disk_one = str(table_data[40])
disk_two = str(table_data[41])
disk_three = str(table_data[42])
disk_four = str(table_data[43])
disk_five = str(table_data[44])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)
# Out:
# ['Accel', 'Blast', 'Blast', 'Charge', 'Charge']

# %%
# table_data 49 through 52 are Connect Info
connect_two_star = str(table_data[45])
connect_three_star = str(table_data[46])
connect_four_star = str(table_data[47])
connect_five_star = str(table_data[48])

connect_two_star = connect_two_star.replace('</td>', '')
connect_two_star = connect_two_star.replace('<td style="width:100%;">', '')
connect_two_star = connect_two_star.rstrip()
print(connect_two_star)

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

connect_five_star = connect_five_star.replace('</td>', '')
connect_five_star = connect_five_star.replace('<td style="width:100%;">', '')
connect_five_star = connect_five_star.rstrip()
print(connect_five_star)
# Out:
# ★2: Damage UP [IV] &amp; Guaranteed Poison Edge
# ★3: Damage UP [VI] &amp; Guaranteed Poison Edge
# ★4: Damage UP [VIII] &amp; Guaranteed Poison Edge
# ★5: Damage UP [X] &amp; Guaranteed Poison Edge

# %%
# table_data 53 through 56 are Magia Info
table_data[58]
magia_two_star = str(table_data[49])
magia_three_star = str(table_data[50])
magia_four_star = str(table_data[51])
magia_five_star = str(table_data[52])

magia_two_star = magia_two_star.replace('</td>', '')
magia_two_star = magia_two_star.replace('<td style="width:100%;">', '')
magia_two_star = magia_two_star.rstrip()
print(magia_two_star)

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

magia_five_star = magia_five_star.replace('</td>', '')
magia_five_star = magia_five_star.replace('<td style="width:100%;">', '')
magia_five_star = magia_five_star.rstrip()
print(magia_five_star)
# Out:
# ★2: Damage All Enemies [I] &amp; Probability Poison (All / 3 T)
# ★3: Damage All Enemies [III] &amp; Probability Poison (All / 3 T)
# ★4: Damage All Enemies [V] &amp; Probability Poison (All / 3 T) &amp; Guaranteed Stun (All / 1 T)
# ★5: Damage All Enemies [VII] &amp; Guaranteed Poison (All / 3 T) &amp; Guaranteed Stun (All / 1 T)

# %%
# table_data 57 is Doppel Info
table_data[53]
doppel_info = str(table_data[57])
doppel_info = doppel_info.replace('<td style="width:100%;">', '')
doppel_info = doppel_info.replace('</td>', '')
doppel_info = doppel_info.rstrip()
print(doppel_info)

table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
doppel = str(table_head[5])
print(magia)
print(doppel)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)

doppel = doppel.strip('<th colspan="5">')
doppel = doppel.strip('b>')
doppel = doppel.replace('<b>', '')
doppel = doppel.replace('</b>', '')
doppel = doppel.replace('<i>', '')
doppel = doppel.replace('</i>', '')
doppel = doppel.strip('</')
doppel = doppel.rstrip()
print(doppel)
# Out:
# <td style="width:25%;text-align:center;"><b>Eng Text</b>
# <th colspan="5"><b>Magia:</b> <i>Atomo Arrabbiata</i>
# </th>
# <th colspan="5"><b>Doppel: <i>Cyan</i></b>
# </th>
# Connect: Here Are Our Research Results!
# Magia: Atomo Arrabbiata
# Doppel: Cyan

# %%
Age = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[25]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[26]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[27]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Witch)
Pronoun = str(bullet_points[28]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[29]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)

Hinano = {
    "Name": "Hinano Miyako",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Two_Star": {
            "HP": two_star_hp,
            "ATK": two_star_atk,
            "DEF": two_star_def 
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "Five_Star": {
            "HP": five_star_hp,
            "ATK": five_star_atk,
            "DEF": five_star_def        
        }
    },
    "Connect": {
        "Name": connect,
        "Two_Star": connect_two_star,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star,
        "Five_Star": connect_five_star
    },
    "Magia": {
        "Name": magia,
        "Two_Star": magia_two_star,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star,
        "Five_Star": magia_five_star
    },
    "Doppel": {
        "Name": doppel,
        "Desc": para,
        "Ability": doppel_info,
    }
}

print(Hinano)
# Out:
# Age: 18
# Height: 145cm
# Eye colour: Amber Green
# Hair colour: Green
# Origins: Chuo Ward
# Soul Gem: Four leaf clover (under her chest)
# Weapon: Chemical-filled <a class="external text" href="https://en.wikipedia.org/wiki/Test_tube" rel="nofollow">test tubes> and <a class="external text" href="https://en.wikipedia.org/wiki/Laboratory_flask" rel="nofollow">flasks
# Wish: To save her life after an experiment went horribly wrong.
# Ability: Chemical Explosion (Turn surroundings into explosives)
# Witch form: Cyan
# Japanese pronoun: <i>atashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">アタシ</span>)</span
# School: Minagi Freedom School Twelfth Grade
# {'Name': 'Hinano Miyako', 'Age': 'Age: 18', 'EyeColor': 'Eye colour: Amber Green', 'HairColor': 'Hair colour: Green', 'Hometown': 'Origins: Chuo Ward', 'SoulGem': 'Soul Gem: Four leaf clover (under her chest)', 'Weapon': 'Weapon: Chemical-filled <a class="external text" href="https://en.wikipedia.org/wiki/Test_tube" rel="nofollow">test tubes> and <a class="external text" href="https://en.wikipedia.org/wiki/Laboratory_flask" rel="nofollow">flasks', 'Wish': 'Wish: To save her life after an experiment went horribly wrong.', 'Ability': 'Ability: Chemical Explosion (Turn surroundings into explosives)', 'Witch': 'Witch form: Cyan', 'Pronoun': 'Japanese pronoun: <i>atashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">アタシ</span>)</span', 'School': 'School: Minagi Freedom School Twelfth Grade', 'Disks': ['Accel', 'Blast', 'Blast', 'Charge', 'Charge'], 'Stats': {'Initial': {'HP': '4101', 'ATK': '1182', 'DEF': '1587'}, 'Two_Star': {'HP': '12114', 'ATK': '3490', 'DEF': '3431'}, 'Three_Star': {'HP': '20189', 'ATK': '5828', 'DEF': '5721'}, 'Four_Star': {'HP': '20189', 'ATK': '5828', 'DEF': '5721'}, 'Five_Star': {'HP': '25030', 'ATK': '7230', 'DEF': '7100'}}, 'Connect': {'Name': 'Connect: Here Are Our Research Results!', 'Two_Star': '★2: Damage UP [IV] &amp; Guaranteed Poison Edge', 'Three_Star': '★3: Damage UP [VI] &amp; Guaranteed Poison Edge', 'Four_Star': '★4: Damage UP [VIII] &amp; Guaranteed Poison Edge', 'Five_Star': '★5: Damage UP [X] &amp; Guaranteed Poison Edge'}, 'Magia': {'Name': 'Magia: Atomo Arrabbiata', 'Two_Star': '★2: Damage All Enemies [I] &amp; Probability Poison (All / 3 T)', 'Three_Star': '★3: Damage All Enemies [III] &amp; Probability Poison (All / 3 T)', 'Four_Star': '★4: Damage All Enemies [V] &amp; Probability Poison (All / 3 T) &amp; Guaranteed Stun (All / 1 T)', 'Five_Star': '★5: Damage All Enemies [VII] &amp; Guaranteed Poison (All / 3 T) &amp; Guaranteed Stun (All / 1 T)'}, 'Doppel': {'Name': 'Doppel: Cyan', 'Desc': 'The Doppel of imprudence. Its form is smog.\nThe master of this Doppel is thrilled with its legs, which have grown much longer. It boils the contents of its right leg and condenses the contents of its left to cause the chemical reaction that forms its gaseous upper body. It therefore boasts a high resistance to physical attacks; however, it also envelops enemy and ally alike in its toxicity. Once it appears, its surroundings are contaminated by its gas, and even its master would likely not be able to withstand it if she did not wear a gas mask. It also has a strong curiosity for rare kinds of Witches.', 'Ability': '<td style="width:25%;text-align:center;"><b>Eng Text</b>'}}

# %%
girl_json = json.dumps(Hinano)
print(girl_json)

with open('hinano.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Hinano Miyako", "Age": "Age: 18", "EyeColor": "Eye colour: Amber Green", "HairColor": "Hair colour: Green", "Hometown": "Origins: Chuo Ward", "SoulGem": "Soul Gem: Four leaf clover (under her chest)", "Weapon": "Weapon: Chemical-filled <a class=\"external text\" href=\"https://en.wikipedia.org/wiki/Test_tube\" rel=\"nofollow\">test tubes> and <a class=\"external text\" href=\"https://en.wikipedia.org/wiki/Laboratory_flask\" rel=\"nofollow\">flasks", "Wish": "Wish: To save her life after an experiment went horribly wrong.", "Ability": "Ability: Chemical Explosion (Turn surroundings into explosives)", "Witch": "Witch form: Cyan", "Pronoun": "Japanese pronoun: <i>atashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u30a2\u30bf\u30b7</span>)</span", "School": "School: Minagi Freedom School Twelfth Grade", "Disks": ["Accel", "Blast", "Blast", "Charge", "Charge"], "Stats": {"Initial": {"HP": "4101", "ATK": "1182", "DEF": "1587"}, "Two_Star": {"HP": "12114", "ATK": "3490", "DEF": "3431"}, "Three_Star": {"HP": "20189", "ATK": "5828", "DEF": "5721"}, "Four_Star": {"HP": "20189", "ATK": "5828", "DEF": "5721"}, "Five_Star": {"HP": "25030", "ATK": "7230", "DEF": "7100"}}, "Connect": {"Name": "Connect: Here Are Our Research Results!", "Two_Star": "\u26052: Damage UP [IV] &amp; Guaranteed Poison Edge", "Three_Star": "\u26053: Damage UP [VI] &amp; Guaranteed Poison Edge", "Four_Star": "\u26054: Damage UP [VIII] &amp; Guaranteed Poison Edge", "Five_Star": "\u26055: Damage UP [X] &amp; Guaranteed Poison Edge"}, "Magia": {"Name": "Magia: Atomo Arrabbiata", "Two_Star": "\u26052: Damage All Enemies [I] &amp; Probability Poison (All / 3 T)", "Three_Star": "\u26053: Damage All Enemies [III] &amp; Probability Poison (All / 3 T)", "Four_Star": "\u26054: Damage All Enemies [V] &amp; Probability Poison (All / 3 T) &amp; Guaranteed Stun (All / 1 T)", "Five_Star": "\u26055: Damage All Enemies [VII] &amp; Guaranteed Poison (All / 3 T) &amp; Guaranteed Stun (All / 1 T)"}, "Doppel": {"Name": "Doppel: Cyan", "Desc": "The Doppel of imprudence. Its form is smog.\nThe master of this Doppel is thrilled with its legs, which have grown much longer. It boils the contents of its right leg and condenses the contents of its left to cause the chemical reaction that forms its gaseous upper body. It therefore boasts a high resistance to physical attacks; however, it also envelops enemy and ally alike in its toxicity. Once it appears, its surroundings are contaminated by its gas, and even its master would likely not be able to withstand it if she did not wear a gas mask. It also has a strong curiosity for rare kinds of Witches.", "Ability": "<td style=\"width:25%;text-align:center;\"><b>Eng Text</b>"}}

# %%
query_url = "https://wiki.puella-magi.net/Sasara_Minagi"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[16])
print(bullet_points[27])
# Out:
# <li><b>Age:</b> 15</li>
# <li><b>School:</b> Kamihama City University Affiliated School, Ninth Grade</li>

# %%
table_data = soup.find_all('td')

initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 2* 28, 29, 30, 31
two_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
two_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 3* 32, 33, 34, 35
three_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 36, 37, 38, 39
four_star_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(two_star_hp, two_star_atk, two_star_def)
print(three_star_hp, three_star_atk, three_star_def)
print(four_star_hp, four_star_atk, four_star_def)

disk_one = str(table_data[36])
disk_two = str(table_data[37])
disk_three = str(table_data[38])
disk_four = str(table_data[39])
disk_five = str(table_data[40])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)

# table_data 49 through 52 are Connect Info
connect_two_star = str(table_data[41])
connect_three_star = str(table_data[42])
connect_four_star = str(table_data[43])

connect_two_star = connect_two_star.replace('</td>', '')
connect_two_star = connect_two_star.replace('<td style="width:100%;">', '')
connect_two_star = connect_two_star.rstrip()
print(connect_two_star)

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

# table_data 53 through 56 are Magia Info

magia_two_star = str(table_data[44])
magia_three_star = str(table_data[45])
magia_four_star = str(table_data[46])

magia_two_star = magia_two_star.replace('</td>', '')
magia_two_star = magia_two_star.replace('<td style="width:100%;">', '')
magia_two_star = magia_two_star.rstrip()
print(magia_two_star)

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
print(magia)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)
# Out:
# 3993 1018 1305
# 12689 3302 4204
# 16076 4185 5327
# 21150 5510 7012
# ['Accel', 'Accel', 'Blast', 'Blast', 'Charge']
# ★2: Defense UP [III] &amp; Damage Cut [III]
# ★3: Defense UP [V] &amp; Damage Cut [V]
# ★4: Defense UP [VII] &amp; Damage Cut [VII]
# ★2: Damage All Enemies [I] &amp; Defense UP (All / 3 T) &amp; Guaranteed Provoke (Self / 1 T)
# ★3: Damage All Enemies [III] &amp; Defense UP (All / 3 T) &amp; Guaranteed Provoke (Self / 1 T)
# ★4: Damage All Enemies [V] &amp; Defense UP (All / 3 T) &amp; Guaranteed Provoke (Self / 1 T) &amp; Endure (Self / 1 T)
# <th colspan="5"><b>Magia:</b> <i>Knight's Resolve</i>
# </th>
# Connect: I'll Protect You!
# Magia: Knight's Resolve

# %%
Age = str(bullet_points[16]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[25]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '').replace('</', '')
print(Witch)
Pronoun = str(bullet_points[26]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[27]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)

Sasara = {
    "Name": "Sasara Minagi",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Two_Star": {
            "HP": two_star_hp,
            "ATK": two_star_atk,
            "DEF": two_star_def 
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        }
    },
    "Connect": {
        "Name": connect,
        "Two_Star": connect_two_star,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star
    },
    "Magia": {
        "Name": magia,
        "Two_Star": magia_two_star,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star
    },
    "Doppel": {
        "Name": ""
    }
}

print(Sasara)
# Out:
# Age: 15
# Height: 156cm
# Eye colour: Red
# Hair colour: Dark Brown / Black
# Origins: Shinsei Ward
# Soul Gem: Red butterfly (hair ornament)
# Weapon: <a class="external text" href="https://en.wikipedia.org/wiki/Rapier" rel="nofollow">Rapier
# Wish: "I want to become a knight who protects people."
# Ability: Provocation (Draw attacks towards self)
# Witch form:
# Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span
# School: Kamihama City University Affiliated School Ninth Grade
# {'Name': 'Sasara Minagi', 'Age': 'Age: 15', 'EyeColor': 'Eye colour: Red', 'HairColor': 'Hair colour: Dark Brown / Black', 'Hometown': 'Origins: Shinsei Ward', 'SoulGem': 'Soul Gem: Red butterfly (hair ornament)', 'Weapon': 'Weapon: <a class="external text" href="https://en.wikipedia.org/wiki/Rapier" rel="nofollow">Rapier', 'Wish': 'Wish: "I want to become a knight who protects people."', 'Ability': 'Ability: Provocation (Draw attacks towards self)', 'Witch': 'Witch form:', 'Pronoun': 'Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'School': 'School: Kamihama City University Affiliated School Ninth Grade', 'Disks': ['Accel', 'Accel', 'Blast', 'Blast', 'Charge'], 'Stats': {'Initial': {'HP': '3993', 'ATK': '1018', 'DEF': '1305'}, 'Two_Star': {'HP': '12689', 'ATK': '3302', 'DEF': '4204'}, 'Three_Star': {'HP': '16076', 'ATK': '4185', 'DEF': '5327'}, 'Four_Star': {'HP': '21150', 'ATK': '5510', 'DEF': '7012'}}, 'Connect': {'Name': "Connect: I'll Protect You!", 'Two_Star': '★2: Defense UP [III] &amp; Damage Cut [III]', 'Three_Star': '★3: Defense UP [V] &amp; Damage Cut [V]', 'Four_Star': '★4: Defense UP [VII] &amp; Damage Cut [VII]'}, 'Magia': {'Name': "Magia: Knight's Resolve", 'Two_Star': '★2: Damage All Enemies [I] &amp; Defense UP (All / 3 T) &amp; Guaranteed Provoke (Self / 1 T)', 'Three_Star': '★3: Damage All Enemies [III] &amp; Defense UP (All / 3 T) &amp; Guaranteed Provoke (Self / 1 T)', 'Four_Star': '★4: Damage All Enemies [V] &amp; Defense UP (All / 3 T) &amp; Guaranteed Provoke (Self / 1 T) &amp; Endure (Self / 1 T)'}, 'Doppel': {'Name': ''}}

# %%
girl_json = json.dumps(Sasara)
print(girl_json)

with open('sasara.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Sasara Minagi", "Age": "Age: 15", "EyeColor": "Eye colour: Red", "HairColor": "Hair colour: Dark Brown / Black", "Hometown": "Origins: Shinsei Ward", "SoulGem": "Soul Gem: Red butterfly (hair ornament)", "Weapon": "Weapon: <a class=\"external text\" href=\"https://en.wikipedia.org/wiki/Rapier\" rel=\"nofollow\">Rapier", "Wish": "Wish: \"I want to become a knight who protects people.\"", "Ability": "Ability: Provocation (Draw attacks towards self)", "Witch": "Witch form:", "Pronoun": "Japanese pronoun: <i>watashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u79c1</span>)</span", "School": "School: Kamihama City University Affiliated School Ninth Grade", "Disks": ["Accel", "Accel", "Blast", "Blast", "Charge"], "Stats": {"Initial": {"HP": "3993", "ATK": "1018", "DEF": "1305"}, "Two_Star": {"HP": "12689", "ATK": "3302", "DEF": "4204"}, "Three_Star": {"HP": "16076", "ATK": "4185", "DEF": "5327"}, "Four_Star": {"HP": "21150", "ATK": "5510", "DEF": "7012"}}, "Connect": {"Name": "Connect: I'll Protect You!", "Two_Star": "\u26052: Defense UP [III] &amp; Damage Cut [III]", "Three_Star": "\u26053: Defense UP [V] &amp; Damage Cut [V]", "Four_Star": "\u26054: Defense UP [VII] &amp; Damage Cut [VII]"}, "Magia": {"Name": "Magia: Knight's Resolve", "Two_Star": "\u26052: Damage All Enemies [I] &amp; Defense UP (All / 3 T) &amp; Guaranteed Provoke (Self / 1 T)", "Three_Star": "\u26053: Damage All Enemies [III] &amp; Defense UP (All / 3 T) &amp; Guaranteed Provoke (Self / 1 T)", "Four_Star": "\u26054: Damage All Enemies [V] &amp; Defense UP (All / 3 T) &amp; Guaranteed Provoke (Self / 1 T) &amp; Endure (Self / 1 T)"}, "Doppel": {"Name": ""}}

# %%
query_url = "https://wiki.puella-magi.net/Nanaka_Tokiwa"
response = requests.get(query_url)
soup = bs(response.text, 'html.parser')

bullet_points = soup.find_all('li')
# 19- 30 General Info
print(bullet_points[15])
print(bullet_points[26])

para = soup.find_all('p')
para = str(para[4])
para = para.strip("<p>")
para = para.strip("</p>")
para = para.rstrip()
print(para)
# Out:
# <li><b>Age:</b> 15</li>
# <li><b>School:</b> Sankyoin Educational Academy, Ninth Grade</li>
# The Doppel of two sides. Its form is a shop curtain. This Doppel reflects two sides of the same coin. The master of this emotion feels guilty in some way about the lack of floral elements in her Doppel. Its frontside primarily supports its allies, while it's back side's offensive powers is high. It is skilled at parrying enemy attacks, and it guides any souls who pass through its curtains to the underworld.

# %%
table_data = soup.find_all('td')

initial_hp = str(table_data[21]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_atk = str(table_data[22]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
initial_def = str(table_data[23]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

# max at 3* 32, 33, 34, 35
three_star_hp = str(table_data[25]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_atk = str(table_data[26]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
three_star_def = str(table_data[27]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 4* 36, 37, 38, 39
four_star_hp = str(table_data[29]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_atk = str(table_data[30]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
four_star_def = str(table_data[31]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# max at 5* [40], [41], [42], [43]
five_star_hp = str(table_data[33]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_atk = str(table_data[34]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
five_star_def = str(table_data[35]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
# Max SE 44, 45, 46, 47
se_hp = str(table_data[37]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_atk = str(table_data[38]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()
se_def = str(table_data[39]).replace('<td style="width:25%;">', '').replace('</td>', '').rstrip()

print(initial_hp, initial_atk, initial_def)
print(three_star_hp, three_star_atk, three_star_def)
print(four_star_hp, four_star_atk, four_star_def)
print(five_star_hp, five_star_atk, five_star_def)
print(se_hp, se_atk, se_def)

disk_one = str(table_data[40])
disk_two = str(table_data[41])
disk_three = str(table_data[42])
disk_four = str(table_data[43])
disk_five = str(table_data[44])

if (disk_one.find("accel") != -1):
    disk_one = "Accel"
elif (disk_one.find("blast") != -1):
    disk_one = "Blast"
else:
    disk_one = "Charge"
    
if (disk_two.find("accel") != -1):
    disk_two = "Accel"
elif (disk_two.find("blast") != -1):
    disk_two = "Blast"
else:
    disk_two = "Charge"

if (disk_three.find("accel") != -1):
    disk_three = "Accel"
elif (disk_three.find("blast") != -1):
    disk_three = "Blast"
else:
    disk_three = "Charge"
    
if (disk_four.find("accel") != -1):
    disk_four = "Accel"
elif (disk_four.find("blast") != -1):
    disk_four = "Blast"
else:
    disk_four = "Charge"
    
if (disk_five.find("accel") != -1):
    disk_five = "Accel"
elif (disk_five.find("blast") != -1):
    disk_five = "Blast"
else:
    disk_five = "Charge"
    
disks = [disk_one, disk_two, disk_three, disk_four, disk_five]
print(disks)

# table_data 49 through 52 are Connect Info
connect_three_star = str(table_data[45])
connect_four_star = str(table_data[46])
connect_five_star = str(table_data[47])

connect_three_star = connect_three_star.replace('</td>', '')
connect_three_star = connect_three_star.replace('<td style="width:100%;">', '')
connect_three_star = connect_three_star.rstrip()
print(connect_three_star)

connect_four_star = connect_four_star.replace('</td>', '')
connect_four_star = connect_four_star.replace('<td style="width:100%;">', '')
connect_four_star = connect_four_star.rstrip()
print(connect_four_star)

connect_five_star = connect_five_star.replace('</td>', '')
connect_five_star = connect_five_star.replace('<td style="width:100%;">', '')
connect_five_star = connect_five_star.rstrip()
print(connect_five_star)

# table_data 53 through 56 are Magia Info

magia_three_star = str(table_data[48])
magia_four_star = str(table_data[49])
magia_five_star = str(table_data[50])

magia_three_star = magia_three_star.replace('</td>', '')
magia_three_star = magia_three_star.replace('<td style="width:100%;">', '')
magia_three_star = magia_three_star.rstrip()
print(magia_three_star)

magia_four_star = magia_four_star.replace('</td>', '')
magia_four_star = magia_four_star.replace('<td style="width:100%;">', '')
magia_four_star = magia_four_star.rstrip()
print(magia_four_star)

magia_five_star = magia_five_star.replace('</td>', '')
magia_five_star = magia_five_star.replace('<td style="width:100%;">', '')
magia_five_star = magia_five_star.rstrip()
print(magia_five_star)

doppel_info = str(table_data[51])
doppel_info = doppel_info.replace('<td style="width:100%;">', '')
doppel_info = doppel_info.replace('</td>', '')
doppel_info = doppel_info.rstrip()
print(doppel_info)

table_head = soup.find_all('th')
connect = str(table_head[3])
magia = str(table_head[4])
doppel = str(table_head[5])
print(magia)
print(doppel)

connect = connect.strip('<th colspan="5">')
connect = connect.strip('b>')
connect = connect.strip('<b>')
connect = connect.replace('</b>', '')
connect = connect.replace('<i>', '')
connect = connect.replace('</i>', '')
connect = connect.strip('</')
connect = connect.rstrip()
print(connect)

magia = magia.strip('<th colspan="5">')
magia = magia.strip('b>')
magia = magia.replace('</b>', '')
magia = magia.replace('<i>', '')
magia = magia.replace('</i>', '')
magia = magia.strip('</')
magia = magia.rstrip()
print(magia)

doppel = doppel.strip('<th colspan="5">')
doppel = doppel.strip('b>')
doppel = doppel.replace('<b>', '')
doppel = doppel.replace('</b>', '')
doppel = doppel.replace('<i>', '')
doppel = doppel.replace('</i>', '')
doppel = doppel.strip('</')
doppel = doppel.rstrip()
print(doppel)
# Out:
# 4625 1484 1476
# 15947 5081 4982
# 20743 6606 6479
# 24648 8136 7797
# 30259 9405 10677
# ['Accel', 'Blast', 'Blast', 'Blast', 'Charge']
# ★3: Blast Damage UP [V] &amp; Attack UP [V]
# ★4: Blast Damage UP [VII] &amp; Attack UP [VII]
# ★5: Blast Damage UP [VII] &amp; Attack UP [VIII] &amp; Debuff (All)
# ★3: Damage All Enemies [III] &amp; Enemy Defense DOWN (All / 3 T)
# ★4: Damage All Enemies [V] &amp; Enemy Defense DOWN (All / 3 T) &amp; Remove Buffs (All Enemies)
# ★5: Damage All Enemies [VII] &amp; Enemy Defense DOWN (All / 3 T) &amp; Remove Buffs (All Enemies)
# Damage All Enemies [IX] &amp; Enemy Defense DOWN (All / 3 T) &amp; Remove Buffs (All Enemies) &amp; Enemy Attack DOWN (All / 3 T)
# <th colspan="5"><b>Magia:</b> <i>White Camellia</i>
# </th>
# <th colspan="5"><b>Doppel:</b> <i>Maura</i>
# </th>
# Connect: What Do You Think of This Plan?
# Magia: White Camellia
# Doppel: Maura

# %%
Age = str(bullet_points[15]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Age)
Height = str(bullet_points[16]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Height)
EyeColor = str(bullet_points[17]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(EyeColor)
HairColor = str(bullet_points[18]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(HairColor)
Hometown = str(bullet_points[19]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Hometown)
SoulGem = str(bullet_points[20]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(SoulGem)
Weapon = str(bullet_points[21]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace('</a', '').replace('<a class="external text" href="https://en.wikipedia.org/wiki/Crossbow" rel="nofollow">', '')
print(Weapon)
Wish = str(bullet_points[22]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Wish)
Ability = str(bullet_points[23]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Ability)
Witch = str(bullet_points[24]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Witch)
Pronoun = str(bullet_points[25]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(Pronoun)
School = str(bullet_points[26]).strip("<li>").strip("</li>").strip("<b>").replace("</b>", "").replace(',', '')
print(School)

Nanaka = {
    "Name": "Nanaka Tokiwa",
    "Age": Age,
    "EyeColor": EyeColor,
    "HairColor": HairColor,
    "Hometown": Hometown,
    "SoulGem": SoulGem,
    "Weapon": Weapon,
    "Wish": Wish,
    "Ability": Ability,
    "Witch": Witch,
    "Pronoun": Pronoun,
    "School": School,
    "Disks": disks,
    "Stats": {
        "Initial": {
            "HP": initial_hp,
            "ATK": initial_atk,
            "DEF": initial_def
        },
        "Three_Star": {
            "HP": three_star_hp,
            "ATK": three_star_atk,
            "DEF": three_star_def
        },
        "Four_Star": {
            "HP": four_star_hp,
            "ATK": four_star_atk,
            "DEF": four_star_def
        },
        "Five_Star": {
            "HP": five_star_hp,
            "ATK": five_star_atk,
            "DEF": five_star_def        
        },
        "SE": {
            "HP": se_hp,
            "ATK": se_atk,
            "DEF":  se_def          
        }
    },
    "Connect": {
        "Name": connect,
        "Three_Star": connect_three_star,
        "Four_Star": connect_four_star,
        "Five_Star": connect_five_star
    },
    "Magia": {
        "Name": magia,
        "Three_Star": magia_three_star,
        "Four_Star": magia_four_star,
        "Five_Star": magia_five_star
    },
    "Doppel": {
        "Name": doppel,
        "Desc": para,
        "Ability": doppel_info,
    }
}

print(Nanaka)
# Out:
# Age: 15
# Height: 160cm
# Eye colour: Magenta
# Hair colour: Magenta
# Origins: Sankyo Ward
# Soul Gem: Hot pink oval (hair ornament)
# Weapon: <a class="external text" href="https://en.wikipedia.org/wiki/Katana" rel="nofollow">Katanas> (Two sword style)
# Wish: "The power to accomplish my revenge by my own hand."
# Ability: Identify true enemies
# Witch form: Maura
# Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span
# School: Sankyoin Educational Academy Ninth Grade
# {'Name': 'Nanaka Tokiwa', 'Age': 'Age: 15', 'EyeColor': 'Eye colour: Magenta', 'HairColor': 'Hair colour: Magenta', 'Hometown': 'Origins: Sankyo Ward', 'SoulGem': 'Soul Gem: Hot pink oval (hair ornament)', 'Weapon': 'Weapon: <a class="external text" href="https://en.wikipedia.org/wiki/Katana" rel="nofollow">Katanas> (Two sword style)', 'Wish': 'Wish: "The power to accomplish my revenge by my own hand."', 'Ability': 'Ability: Identify true enemies', 'Witch': 'Witch form: Maura', 'Pronoun': 'Japanese pronoun: <i>watashi</i><span style="font-weight: normal"> (<span class="t_nihongo_kanji" lang="ja">私</span>)</span', 'School': 'School: Sankyoin Educational Academy Ninth Grade', 'Disks': ['Accel', 'Blast', 'Blast', 'Blast', 'Charge'], 'Stats': {'Initial': {'HP': '4625', 'ATK': '1484', 'DEF': '1476'}, 'Three_Star': {'HP': '15947', 'ATK': '5081', 'DEF': '4982'}, 'Four_Star': {'HP': '20743', 'ATK': '6606', 'DEF': '6479'}, 'Five_Star': {'HP': '24648', 'ATK': '8136', 'DEF': '7797'}, 'SE': {'HP': '30259', 'ATK': '9405', 'DEF': '10677'}}, 'Connect': {'Name': 'Connect: What Do You Think of This Plan?', 'Three_Star': '★3: Blast Damage UP [V] &amp; Attack UP [V]', 'Four_Star': '★4: Blast Damage UP [VII] &amp; Attack UP [VII]', 'Five_Star': '★5: Blast Damage UP [VII] &amp; Attack UP [VIII] &amp; Debuff (All)'}, 'Magia': {'Name': 'Magia: White Camellia', 'Three_Star': '★3: Damage All Enemies [III] &amp; Enemy Defense DOWN (All / 3 T)', 'Four_Star': '★4: Damage All Enemies [V] &amp; Enemy Defense DOWN (All / 3 T) &amp; Remove Buffs (All Enemies)', 'Five_Star': '★5: Damage All Enemies [VII] &amp; Enemy Defense DOWN (All / 3 T) &amp; Remove Buffs (All Enemies)'}, 'Doppel': {'Name': 'Doppel: Maura', 'Desc': "The Doppel of two sides. Its form is a shop curtain. This Doppel reflects two sides of the same coin. The master of this emotion feels guilty in some way about the lack of floral elements in her Doppel. Its frontside primarily supports its allies, while it's back side's offensive powers is high. It is skilled at parrying enemy attacks, and it guides any souls who pass through its curtains to the underworld.", 'Ability': 'Damage All Enemies [IX] &amp; Enemy Defense DOWN (All / 3 T) &amp; Remove Buffs (All Enemies) &amp; Enemy Attack DOWN (All / 3 T)'}}

# %%
girl_json = json.dumps(Nanaka)
print(girl_json)

with open('nanaka.json', 'w') as json_file:
  json.dump(girl_json, json_file)
# Out:
# {"Name": "Nanaka Tokiwa", "Age": "Age: 15", "EyeColor": "Eye colour: Magenta", "HairColor": "Hair colour: Magenta", "Hometown": "Origins: Sankyo Ward", "SoulGem": "Soul Gem: Hot pink oval (hair ornament)", "Weapon": "Weapon: <a class=\"external text\" href=\"https://en.wikipedia.org/wiki/Katana\" rel=\"nofollow\">Katanas> (Two sword style)", "Wish": "Wish: \"The power to accomplish my revenge by my own hand.\"", "Ability": "Ability: Identify true enemies", "Witch": "Witch form: Maura", "Pronoun": "Japanese pronoun: <i>watashi</i><span style=\"font-weight: normal\"> (<span class=\"t_nihongo_kanji\" lang=\"ja\">\u79c1</span>)</span", "School": "School: Sankyoin Educational Academy Ninth Grade", "Disks": ["Accel", "Blast", "Blast", "Blast", "Charge"], "Stats": {"Initial": {"HP": "4625", "ATK": "1484", "DEF": "1476"}, "Three_Star": {"HP": "15947", "ATK": "5081", "DEF": "4982"}, "Four_Star": {"HP": "20743", "ATK": "6606", "DEF": "6479"}, "Five_Star": {"HP": "24648", "ATK": "8136", "DEF": "7797"}, "SE": {"HP": "30259", "ATK": "9405", "DEF": "10677"}}, "Connect": {"Name": "Connect: What Do You Think of This Plan?", "Three_Star": "\u26053: Blast Damage UP [V] &amp; Attack UP [V]", "Four_Star": "\u26054: Blast Damage UP [VII] &amp; Attack UP [VII]", "Five_Star": "\u26055: Blast Damage UP [VII] &amp; Attack UP [VIII] &amp; Debuff (All)"}, "Magia": {"Name": "Magia: White Camellia", "Three_Star": "\u26053: Damage All Enemies [III] &amp; Enemy Defense DOWN (All / 3 T)", "Four_Star": "\u26054: Damage All Enemies [V] &amp; Enemy Defense DOWN (All / 3 T) &amp; Remove Buffs (All Enemies)", "Five_Star": "\u26055: Damage All Enemies [VII] &amp; Enemy Defense DOWN (All / 3 T) &amp; Remove Buffs (All Enemies)"}, "Doppel": {"Name": "Doppel: Maura", "Desc": "The Doppel of two sides. Its form is a shop curtain. This Doppel reflects two sides of the same coin. The master of this emotion feels guilty in some way about the lack of floral elements in her Doppel. Its frontside primarily supports its allies, while it's back side's offensive powers is high. It is skilled at parrying enemy attacks, and it guides any souls who pass through its curtains to the underworld.", "Ability": "Damage All Enemies [IX] &amp; Enemy Defense DOWN (All / 3 T) &amp; Remove Buffs (All Enemies) &amp; Enemy Attack DOWN (All / 3 T)"}}
